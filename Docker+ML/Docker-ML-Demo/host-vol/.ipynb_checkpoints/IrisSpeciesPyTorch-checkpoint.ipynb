# %% [markdown]
# # Iris Species Classification with PyTorch
# For details, see also
# - https://github.com/pratibhashinde/Project-Iris-PyTorch/blob/master/iris_pytorch.ipynb (primary code source),
# - https://pytorch.org/tutorials/beginner/saving_loading_models.html (on saving and loading pytorch models), and
# - ddd (docker tutorial to which this notebook belongs).
#
# Start by importing required libraries and the iris dataset from the *iris.csv* file. Of course, the iris dataset could also be imported via `from sklearn.datasets import load_iris` but within the docker tutorial (see third link above), we also want to demonstrate the usage of **volumes** that make files on the host (like *iris.csv*) available to a program inside a running docker container (like this jupyter notebook).

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import path
from sklearn.metrics import accuracy_score
np.random.seed(7)
# load and display data
df = pd.read_csv('iris.csv')
print(df)
# converting name (=species) labels to 0, 1, 2
df.loc[df.Name=='Iris-setosa', 'Name'] = 0
df.loc[df.Name=='Iris-versicolor', 'Name'] = 1
df.loc[df.Name=='Iris-virginica', 'Name'] = 2
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]
#      SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0            5.1         3.5          1.4         0.2    0
# 1            4.9         3.0          1.4         0.2    0
# 2            4.7         3.2          1.3         0.2    0
# 3            4.6         3.1          1.5         0.2    0
# 4            5.0         3.6          1.4         0.2    0
# ..           ...         ...          ...         ...  ...
# 145          6.7         3.0          5.2         2.3    2
# 146          6.3         2.5          5.0         1.9    2
# 147          6.5         3.0          5.2         2.0    2
# 148          6.2         3.4          5.4         2.3    2
# 149          5.9         3.0          5.1         1.8    2
#
# [150 rows x 5 columns]

# %% [markdown]
# We have imported the data and converted the iris species *iris-setosa*, *iris-versicolor*, and *iris-virginica* to integer values 0, 1, and 2, respectively. Now, we split the dataset into features X and labels Y, shuffle the instances, and divide it into subsets for training, validation, and testing.

# %%
split_ratio = 0.8
X = df[df.columns[0:4]].values
Y = df[df.columns[4]].values.astype(int)
shuffle_indices = np.random.permutation(len(Y))
print(shuffle_indices[:10])
X , Y = X[shuffle_indices], Y[shuffle_indices]
print(len(Y))
split_1 = int(np.round(split_ratio * len(Y)))
split_2 = int(np.round(split_ratio * split_1))
X, X_test = X[:split_1], X[split_1:]
Y, Y_test = Y[:split_1], Y[split_1:]
print(len(X), len(X_test))
print(len(Y), len(Y_test))
print(split_1)
X, X_valid = X[:split_2], X[split_2:]
Y, Y_valid = Y[:split_2], Y[split_2:]
print(len(X), len(X_valid))
print(len(Y), len(Y_valid))
X[:10], Y[:10]
# Out:
# [149  84  40  66 106  41  52  94  11  51]
# 150
# 120 30
# 120 30
# 120
# 96 24
# 96 24
# (array([[5.9, 3. , 5.1, 1.8],
#         [5.4, 3. , 4.5, 1.5],
#         [5. , 3.5, 1.3, 0.3],
#         [5.6, 3. , 4.5, 1.5],
#         [4.9, 2.5, 4.5, 1.7],
#         [4.5, 2.3, 1.3, 0.3],
#         [6.9, 3.1, 4.9, 1.5],
#         [5.6, 2.7, 4.2, 1.3],
#         [4.8, 3.4, 1.6, 0.2],
#         [6.4, 3.2, 4.5, 1.5]]),
#  array([2, 1, 0, 1, 2, 0, 1, 1, 0, 1]))

# %% [markdown]
# Since the iris dataset does not have many instances (namely 150) to start with, we need to make sure that classes are similarly represented in all subsets (training, validation, and testing).

# %%
def checkClasses(y):
    counts = [0, 0, 0]
    for i in range(len(y)):
        counts[y[i]] += 1
    return counts
checkClasses(Y), checkClasses(Y_valid), checkClasses(Y_test)
# Out:
# ([32, 31, 33], [9, 7, 8], [9, 12, 9])

# %% [markdown]
# We are pretty much done with preparing the dataset and now turn to the neural net. First of all, we convert the input data into tensor format. Then, we define a class for a fully connected neural net and instatiate a net with two hidden layers where each of them has 6 neurons. As demanded by the three different classes, the output layer has three neurons that feed into a softmax activation function. We also define a filepath for saving the model.

# %%
X, Y = torch.Tensor(X).float(), torch.Tensor(Y)
X_valid, Y_valid = torch.Tensor(X_valid).float(), torch.Tensor(Y_valid)
X_test, Y_test = torch.Tensor(X_test).float(), torch.Tensor(Y_test)
# define model class
class net(nn.Module):
    def __init__(self, hidden_1, hidden_2):
        super(net, self).__init__()
        self.f1 = nn.Linear(4, hidden_1)
        self.a1 = nn.ReLU()
        self.f2 = nn.Linear(hidden_1, hidden_2)
        self.f3 = nn.Linear(hidden_2, 3)
        self.softmax = nn.Softmax(dim=1)
    def forward(self, x):
        x = self.f1(x)
        x = self.a1(x)
        x = self.f2(x)
        x = self.f3(x)
        x = self.softmax(x)
        return x
# build model instance and define the path for the saved model
model = net(6, 6)
model_path = './iris_model.pth'

# %% [markdown]
# If there exists a saved model file from a previous training run, we can choose to load it and skip training. If such file does not exist or we choose not to load it the model will be trained and a model file will be created.
#
# The main point here is not so much the training but the **creation of a file** (namely the file of the trained and saved model) that persists in the docker volume **beyond the lifetime of the docker container**. And it goes both ways: after stopping the container and starting a new one from the same image (while also mounting the same volume), the saved model file will still be available from inside the new docker container.

# %%
train = 1
# check for a saved model file from a previous training run
if path.exists(model_path):
    # if a model has been saved, decide whether to load it or not
    answer = input('Load the pretrained model? [0=no, everything else=yes] ')
    if answer!='0':
        train = 0
# if there is a pretrained model AND it shall be loaded, then do load it ...
if train==0:
    model.load_state_dict(torch.load(model_path))
    print('The pretrained model has been loaded.')
# ... otherwise, train the model from scratch (and save the trained model)
else:
    print('Training the model ...')
    # loss and optimizer
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    # train the model
    epochs = 5000
    losses = []
    valid_accs = []
    max_valid_acc = 0
    stagnation_count = 0
    stagnation_threshold = 1500
    for epoch in range(epochs):
        # predictions, loss, gradient, gradient step
        Y_pred = model(X)
        loss = loss_fn(Y_pred, Y.long())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # accuracy on validation set
        Y_valid_logits = model(X_valid)
        _, Y_valid_pred = torch.max(Y_valid_logits, 1)
        valid_acc = accuracy_score(Y_valid_pred, Y_valid)
        # log loss and accuracy
        losses.append(loss.item())
        valid_accs.append(valid_acc)
        # print output
        print('Epoch: {:d}\tLoss: {:.4f}\tAccuracy on validation set: {:.4f}'.format(epoch, loss.item(), valid_acc))
        # early stopping
        if valid_acc > max_valid_acc:
            #torch.save(model, model_path)
            torch.save(model.state_dict(), model_path)
            max_valid_acc = valid_acc
            stagnation_count = 0
            print('Accuracy on validation set has just improved!')
            print ('The model has been saved under ' + model_path + '.')
        else:
            stagnation_count += 1
            if stagnation_count > stagnation_threshold:
                print('Early stopping!')
                break
    # make a nice plot showing the loss (on training set) and the accuary (on validation set) over epochs
    fig, ax1 = plt.subplots()
    color1 = 'tab:red'
    ax1.set_xlabel('epochs')
    ax1.set_ylabel('loss (training set)', color=color1)
    ax1.plot(losses, color=color1)
    ax1.tick_params(axis='y', labelcolor=color1)
    ax2 = ax1.twinx()
    color2 = 'tab:blue'
    ax2.set_ylabel('accuracy (validation set)', color=color2)
    ax2.plot(valid_accs, color=color2)
    ax2.tick_params(axis='y', labelcolor=color2)
    fig.tight_layout()
    plt.show()
# Out:
# Training the model ...
# Epoch: 0	Loss: 1.0901	Accuracy on validation set: 0.3333
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 1	Loss: 1.0896	Accuracy on validation set: 0.3333
# Epoch: 2	Loss: 1.0892	Accuracy on validation set: 0.3333
# Epoch: 3	Loss: 1.0887	Accuracy on validation set: 0.3333
# Epoch: 4	Loss: 1.0882	Accuracy on validation set: 0.3333
# Epoch: 5	Loss: 1.0878	Accuracy on validation set: 0.3333
# Epoch: 6	Loss: 1.0874	Accuracy on validation set: 0.3333
# Epoch: 7	Loss: 1.0869	Accuracy on validation set: 0.3333
# Epoch: 8	Loss: 1.0865	Accuracy on validation set: 0.3333
# Epoch: 9	Loss: 1.0861	Accuracy on validation set: 0.3333
# Epoch: 10	Loss: 1.0857	Accuracy on validation set: 0.3333
# Epoch: 11	Loss: 1.0853	Accuracy on validation set: 0.3333
# Epoch: 12	Loss: 1.0849	Accuracy on validation set: 0.3333
# Epoch: 13	Loss: 1.0846	Accuracy on validation set: 0.3333
# Epoch: 14	Loss: 1.0842	Accuracy on validation set: 0.3333
# Epoch: 15	Loss: 1.0839	Accuracy on validation set: 0.3333
# Epoch: 16	Loss: 1.0836	Accuracy on validation set: 0.3333
# Epoch: 17	Loss: 1.0833	Accuracy on validation set: 0.3333
# Epoch: 18	Loss: 1.0830	Accuracy on validation set: 0.3333
# Epoch: 19	Loss: 1.0828	Accuracy on validation set: 0.3333
# Epoch: 20	Loss: 1.0825	Accuracy on validation set: 0.3333
# Epoch: 21	Loss: 1.0822	Accuracy on validation set: 0.3333
# Epoch: 22	Loss: 1.0820	Accuracy on validation set: 0.3333
# Epoch: 23	Loss: 1.0818	Accuracy on validation set: 0.3333
# Epoch: 24	Loss: 1.0816	Accuracy on validation set: 0.3333
# Epoch: 25	Loss: 1.0814	Accuracy on validation set: 0.3333
# Epoch: 26	Loss: 1.0812	Accuracy on validation set: 0.3333
# Epoch: 27	Loss: 1.0810	Accuracy on validation set: 0.3333
# Epoch: 28	Loss: 1.0808	Accuracy on validation set: 0.3333
# Epoch: 29	Loss: 1.0806	Accuracy on validation set: 0.3333
# Epoch: 30	Loss: 1.0805	Accuracy on validation set: 0.3333
# Epoch: 31	Loss: 1.0803	Accuracy on validation set: 0.3333
# Epoch: 32	Loss: 1.0801	Accuracy on validation set: 0.3333
# Epoch: 33	Loss: 1.0800	Accuracy on validation set: 0.3333
# Epoch: 34	Loss: 1.0798	Accuracy on validation set: 0.3333
# Epoch: 35	Loss: 1.0796	Accuracy on validation set: 0.3333
# Epoch: 36	Loss: 1.0795	Accuracy on validation set: 0.3333
# Epoch: 37	Loss: 1.0793	Accuracy on validation set: 0.3333
# Epoch: 38	Loss: 1.0792	Accuracy on validation set: 0.3333
# Epoch: 39	Loss: 1.0790	Accuracy on validation set: 0.3333
# Epoch: 40	Loss: 1.0788	Accuracy on validation set: 0.3333
# Epoch: 41	Loss: 1.0787	Accuracy on validation set: 0.3333
# Epoch: 42	Loss: 1.0785	Accuracy on validation set: 0.3333
# Epoch: 43	Loss: 1.0784	Accuracy on validation set: 0.3333
# Epoch: 44	Loss: 1.0782	Accuracy on validation set: 0.3333
# Epoch: 45	Loss: 1.0781	Accuracy on validation set: 0.3333
# Epoch: 46	Loss: 1.0779	Accuracy on validation set: 0.3333
# Epoch: 47	Loss: 1.0778	Accuracy on validation set: 0.3333
# Epoch: 48	Loss: 1.0776	Accuracy on validation set: 0.3333
# Epoch: 49	Loss: 1.0775	Accuracy on validation set: 0.3333
# Epoch: 50	Loss: 1.0773	Accuracy on validation set: 0.3333
# Epoch: 51	Loss: 1.0772	Accuracy on validation set: 0.3333
# Epoch: 52	Loss: 1.0771	Accuracy on validation set: 0.3333
# Epoch: 53	Loss: 1.0769	Accuracy on validation set: 0.3333
# Epoch: 54	Loss: 1.0768	Accuracy on validation set: 0.3333
# Epoch: 55	Loss: 1.0766	Accuracy on validation set: 0.3333
# Epoch: 56	Loss: 1.0765	Accuracy on validation set: 0.3333
# Epoch: 57	Loss: 1.0763	Accuracy on validation set: 0.3333
# Epoch: 58	Loss: 1.0762	Accuracy on validation set: 0.3333
# Epoch: 59	Loss: 1.0760	Accuracy on validation set: 0.3333
# Epoch: 60	Loss: 1.0759	Accuracy on validation set: 0.3333
# Epoch: 61	Loss: 1.0758	Accuracy on validation set: 0.3333
# Epoch: 62	Loss: 1.0756	Accuracy on validation set: 0.3333
# Epoch: 63	Loss: 1.0755	Accuracy on validation set: 0.3333
# Epoch: 64	Loss: 1.0753	Accuracy on validation set: 0.3333
# Epoch: 65	Loss: 1.0752	Accuracy on validation set: 0.3333
# Epoch: 66	Loss: 1.0751	Accuracy on validation set: 0.3333
# Epoch: 67	Loss: 1.0749	Accuracy on validation set: 0.3333
# Epoch: 68	Loss: 1.0748	Accuracy on validation set: 0.3333
# Epoch: 69	Loss: 1.0746	Accuracy on validation set: 0.3333
# Epoch: 70	Loss: 1.0745	Accuracy on validation set: 0.3333
# Epoch: 71	Loss: 1.0743	Accuracy on validation set: 0.3333
# Epoch: 72	Loss: 1.0742	Accuracy on validation set: 0.3333
# Epoch: 73	Loss: 1.0741	Accuracy on validation set: 0.3333
# Epoch: 74	Loss: 1.0739	Accuracy on validation set: 0.3333
# Epoch: 75	Loss: 1.0738	Accuracy on validation set: 0.3333
# Epoch: 76	Loss: 1.0736	Accuracy on validation set: 0.3333
# Epoch: 77	Loss: 1.0735	Accuracy on validation set: 0.3333
# Epoch: 78	Loss: 1.0734	Accuracy on validation set: 0.3333
# Epoch: 79	Loss: 1.0732	Accuracy on validation set: 0.3333
# Epoch: 80	Loss: 1.0731	Accuracy on validation set: 0.3333
# Epoch: 81	Loss: 1.0730	Accuracy on validation set: 0.3333
# Epoch: 82	Loss: 1.0728	Accuracy on validation set: 0.3333
# Epoch: 83	Loss: 1.0727	Accuracy on validation set: 0.3333
# Epoch: 84	Loss: 1.0725	Accuracy on validation set: 0.3333
# Epoch: 85	Loss: 1.0724	Accuracy on validation set: 0.3333
# Epoch: 86	Loss: 1.0723	Accuracy on validation set: 0.3333
# Epoch: 87	Loss: 1.0721	Accuracy on validation set: 0.3333
# Epoch: 88	Loss: 1.0720	Accuracy on validation set: 0.3333
# Epoch: 89	Loss: 1.0718	Accuracy on validation set: 0.3333
# Epoch: 90	Loss: 1.0717	Accuracy on validation set: 0.3333
# Epoch: 91	Loss: 1.0716	Accuracy on validation set: 0.3333
# Epoch: 92	Loss: 1.0714	Accuracy on validation set: 0.3333
# Epoch: 93	Loss: 1.0713	Accuracy on validation set: 0.3333
# Epoch: 94	Loss: 1.0711	Accuracy on validation set: 0.3333
# Epoch: 95	Loss: 1.0710	Accuracy on validation set: 0.3333
# Epoch: 96	Loss: 1.0708	Accuracy on validation set: 0.3333
# Epoch: 97	Loss: 1.0707	Accuracy on validation set: 0.3333
# Epoch: 98	Loss: 1.0706	Accuracy on validation set: 0.3333
# Epoch: 99	Loss: 1.0704	Accuracy on validation set: 0.3333
# Epoch: 100	Loss: 1.0703	Accuracy on validation set: 0.3333
# Epoch: 101	Loss: 1.0701	Accuracy on validation set: 0.3333
# Epoch: 102	Loss: 1.0700	Accuracy on validation set: 0.3333
# Epoch: 103	Loss: 1.0699	Accuracy on validation set: 0.3333
# Epoch: 104	Loss: 1.0697	Accuracy on validation set: 0.3333
# Epoch: 105	Loss: 1.0696	Accuracy on validation set: 0.3333
# Epoch: 106	Loss: 1.0694	Accuracy on validation set: 0.3333
# Epoch: 107	Loss: 1.0693	Accuracy on validation set: 0.3333
# Epoch: 108	Loss: 1.0691	Accuracy on validation set: 0.3333
# Epoch: 109	Loss: 1.0690	Accuracy on validation set: 0.3333
# Epoch: 110	Loss: 1.0688	Accuracy on validation set: 0.3333
# Epoch: 111	Loss: 1.0687	Accuracy on validation set: 0.3333
# Epoch: 112	Loss: 1.0686	Accuracy on validation set: 0.3333
# Epoch: 113	Loss: 1.0684	Accuracy on validation set: 0.3333
# Epoch: 114	Loss: 1.0683	Accuracy on validation set: 0.3333
# Epoch: 115	Loss: 1.0681	Accuracy on validation set: 0.3333
# Epoch: 116	Loss: 1.0680	Accuracy on validation set: 0.3333
# Epoch: 117	Loss: 1.0678	Accuracy on validation set: 0.3333
# Epoch: 118	Loss: 1.0677	Accuracy on validation set: 0.3333
# Epoch: 119	Loss: 1.0675	Accuracy on validation set: 0.3333
# Epoch: 120	Loss: 1.0674	Accuracy on validation set: 0.3333
# Epoch: 121	Loss: 1.0672	Accuracy on validation set: 0.3333
# Epoch: 122	Loss: 1.0671	Accuracy on validation set: 0.3333
# Epoch: 123	Loss: 1.0669	Accuracy on validation set: 0.3333
# Epoch: 124	Loss: 1.0668	Accuracy on validation set: 0.3333
# Epoch: 125	Loss: 1.0666	Accuracy on validation set: 0.3333
# Epoch: 126	Loss: 1.0665	Accuracy on validation set: 0.3333
# Epoch: 127	Loss: 1.0663	Accuracy on validation set: 0.3333
# Epoch: 128	Loss: 1.0662	Accuracy on validation set: 0.3333
# Epoch: 129	Loss: 1.0660	Accuracy on validation set: 0.3333
# Epoch: 130	Loss: 1.0659	Accuracy on validation set: 0.3333
# Epoch: 131	Loss: 1.0657	Accuracy on validation set: 0.3333
# Epoch: 132	Loss: 1.0656	Accuracy on validation set: 0.3333
# Epoch: 133	Loss: 1.0654	Accuracy on validation set: 0.3333
# Epoch: 134	Loss: 1.0653	Accuracy on validation set: 0.3333
# Epoch: 135	Loss: 1.0651	Accuracy on validation set: 0.3333
# Epoch: 136	Loss: 1.0650	Accuracy on validation set: 0.3333
# Epoch: 137	Loss: 1.0648	Accuracy on validation set: 0.3333
# Epoch: 138	Loss: 1.0646	Accuracy on validation set: 0.3333
# Epoch: 139	Loss: 1.0645	Accuracy on validation set: 0.3333
# Epoch: 140	Loss: 1.0643	Accuracy on validation set: 0.3333
# Epoch: 141	Loss: 1.0642	Accuracy on validation set: 0.3333
# Epoch: 142	Loss: 1.0640	Accuracy on validation set: 0.3333
# Epoch: 143	Loss: 1.0639	Accuracy on validation set: 0.3333
# Epoch: 144	Loss: 1.0637	Accuracy on validation set: 0.3333
# Epoch: 145	Loss: 1.0635	Accuracy on validation set: 0.3333
# Epoch: 146	Loss: 1.0634	Accuracy on validation set: 0.3333
# Epoch: 147	Loss: 1.0632	Accuracy on validation set: 0.3333
# Epoch: 148	Loss: 1.0631	Accuracy on validation set: 0.3333
# Epoch: 149	Loss: 1.0629	Accuracy on validation set: 0.3333
# Epoch: 150	Loss: 1.0627	Accuracy on validation set: 0.3333
# Epoch: 151	Loss: 1.0626	Accuracy on validation set: 0.3333
# Epoch: 152	Loss: 1.0624	Accuracy on validation set: 0.3333
# Epoch: 153	Loss: 1.0623	Accuracy on validation set: 0.3333
# Epoch: 154	Loss: 1.0621	Accuracy on validation set: 0.3333
# Epoch: 155	Loss: 1.0619	Accuracy on validation set: 0.3333
# Epoch: 156	Loss: 1.0618	Accuracy on validation set: 0.3333
# Epoch: 157	Loss: 1.0616	Accuracy on validation set: 0.3333
# Epoch: 158	Loss: 1.0614	Accuracy on validation set: 0.3333
# Epoch: 159	Loss: 1.0613	Accuracy on validation set: 0.3333
# Epoch: 160	Loss: 1.0611	Accuracy on validation set: 0.3333
# Epoch: 161	Loss: 1.0609	Accuracy on validation set: 0.3333
# Epoch: 162	Loss: 1.0608	Accuracy on validation set: 0.3333
# Epoch: 163	Loss: 1.0606	Accuracy on validation set: 0.3333
# Epoch: 164	Loss: 1.0604	Accuracy on validation set: 0.3333
# Epoch: 165	Loss: 1.0602	Accuracy on validation set: 0.3333
# Epoch: 166	Loss: 1.0601	Accuracy on validation set: 0.3333
# Epoch: 167	Loss: 1.0599	Accuracy on validation set: 0.3333
# Epoch: 168	Loss: 1.0597	Accuracy on validation set: 0.3333
# Epoch: 169	Loss: 1.0595	Accuracy on validation set: 0.3333
# Epoch: 170	Loss: 1.0594	Accuracy on validation set: 0.3333
# Epoch: 171	Loss: 1.0592	Accuracy on validation set: 0.3333
# Epoch: 172	Loss: 1.0590	Accuracy on validation set: 0.3333
# Epoch: 173	Loss: 1.0588	Accuracy on validation set: 0.3333
# Epoch: 174	Loss: 1.0587	Accuracy on validation set: 0.3333
# Epoch: 175	Loss: 1.0585	Accuracy on validation set: 0.3333
# Epoch: 176	Loss: 1.0583	Accuracy on validation set: 0.3333
# Epoch: 177	Loss: 1.0581	Accuracy on validation set: 0.3333
# Epoch: 178	Loss: 1.0580	Accuracy on validation set: 0.3333
# Epoch: 179	Loss: 1.0578	Accuracy on validation set: 0.3333
# Epoch: 180	Loss: 1.0576	Accuracy on validation set: 0.3333
# Epoch: 181	Loss: 1.0574	Accuracy on validation set: 0.3333
# Epoch: 182	Loss: 1.0572	Accuracy on validation set: 0.3333
# Epoch: 183	Loss: 1.0570	Accuracy on validation set: 0.3333
# Epoch: 184	Loss: 1.0569	Accuracy on validation set: 0.3333
# Epoch: 185	Loss: 1.0567	Accuracy on validation set: 0.3333
# Epoch: 186	Loss: 1.0565	Accuracy on validation set: 0.3333
# Epoch: 187	Loss: 1.0563	Accuracy on validation set: 0.3333
# Epoch: 188	Loss: 1.0561	Accuracy on validation set: 0.3333
# Epoch: 189	Loss: 1.0559	Accuracy on validation set: 0.3333
# Epoch: 190	Loss: 1.0557	Accuracy on validation set: 0.3333
# Epoch: 191	Loss: 1.0555	Accuracy on validation set: 0.3333
# Epoch: 192	Loss: 1.0553	Accuracy on validation set: 0.3333
# Epoch: 193	Loss: 1.0552	Accuracy on validation set: 0.3333
# Epoch: 194	Loss: 1.0550	Accuracy on validation set: 0.3333
# Epoch: 195	Loss: 1.0548	Accuracy on validation set: 0.3333
# Epoch: 196	Loss: 1.0546	Accuracy on validation set: 0.3333
# Epoch: 197	Loss: 1.0544	Accuracy on validation set: 0.3333
# Epoch: 198	Loss: 1.0542	Accuracy on validation set: 0.3333
# Epoch: 199	Loss: 1.0540	Accuracy on validation set: 0.3333
# Epoch: 200	Loss: 1.0538	Accuracy on validation set: 0.3333
# Epoch: 201	Loss: 1.0536	Accuracy on validation set: 0.3333
# Epoch: 202	Loss: 1.0534	Accuracy on validation set: 0.3333
# Epoch: 203	Loss: 1.0532	Accuracy on validation set: 0.3333
# Epoch: 204	Loss: 1.0530	Accuracy on validation set: 0.3333
# Epoch: 205	Loss: 1.0528	Accuracy on validation set: 0.3333
# Epoch: 206	Loss: 1.0526	Accuracy on validation set: 0.3333
# Epoch: 207	Loss: 1.0524	Accuracy on validation set: 0.3333
# Epoch: 208	Loss: 1.0522	Accuracy on validation set: 0.3333
# Epoch: 209	Loss: 1.0520	Accuracy on validation set: 0.3333
# Epoch: 210	Loss: 1.0517	Accuracy on validation set: 0.3333
# Epoch: 211	Loss: 1.0515	Accuracy on validation set: 0.3333
# Epoch: 212	Loss: 1.0513	Accuracy on validation set: 0.3333
# Epoch: 213	Loss: 1.0511	Accuracy on validation set: 0.3333
# Epoch: 214	Loss: 1.0509	Accuracy on validation set: 0.3333
# Epoch: 215	Loss: 1.0507	Accuracy on validation set: 0.3333
# Epoch: 216	Loss: 1.0505	Accuracy on validation set: 0.3333
# Epoch: 217	Loss: 1.0503	Accuracy on validation set: 0.3333
# Epoch: 218	Loss: 1.0500	Accuracy on validation set: 0.3333
# Epoch: 219	Loss: 1.0498	Accuracy on validation set: 0.3333
# Epoch: 220	Loss: 1.0496	Accuracy on validation set: 0.3333
# Epoch: 221	Loss: 1.0494	Accuracy on validation set: 0.3333
# Epoch: 222	Loss: 1.0492	Accuracy on validation set: 0.3333
# Epoch: 223	Loss: 1.0490	Accuracy on validation set: 0.3333
# Epoch: 224	Loss: 1.0487	Accuracy on validation set: 0.3333
# Epoch: 225	Loss: 1.0485	Accuracy on validation set: 0.3333
# Epoch: 226	Loss: 1.0483	Accuracy on validation set: 0.3333
# Epoch: 227	Loss: 1.0481	Accuracy on validation set: 0.3333
# Epoch: 228	Loss: 1.0478	Accuracy on validation set: 0.3333
# Epoch: 229	Loss: 1.0476	Accuracy on validation set: 0.3333
# Epoch: 230	Loss: 1.0474	Accuracy on validation set: 0.3333
# Epoch: 231	Loss: 1.0471	Accuracy on validation set: 0.3333
# Epoch: 232	Loss: 1.0469	Accuracy on validation set: 0.3333
# Epoch: 233	Loss: 1.0467	Accuracy on validation set: 0.3333
# Epoch: 234	Loss: 1.0464	Accuracy on validation set: 0.3333
# Epoch: 235	Loss: 1.0462	Accuracy on validation set: 0.3333
# Epoch: 236	Loss: 1.0460	Accuracy on validation set: 0.3333
# Epoch: 237	Loss: 1.0457	Accuracy on validation set: 0.3333
# Epoch: 238	Loss: 1.0455	Accuracy on validation set: 0.3333
# Epoch: 239	Loss: 1.0452	Accuracy on validation set: 0.3750
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 240	Loss: 1.0450	Accuracy on validation set: 0.3750
# Epoch: 241	Loss: 1.0448	Accuracy on validation set: 0.3750
# Epoch: 242	Loss: 1.0445	Accuracy on validation set: 0.3750
# Epoch: 243	Loss: 1.0443	Accuracy on validation set: 0.3750
# Epoch: 244	Loss: 1.0440	Accuracy on validation set: 0.3750
# Epoch: 245	Loss: 1.0438	Accuracy on validation set: 0.3750
# Epoch: 246	Loss: 1.0435	Accuracy on validation set: 0.3750
# Epoch: 247	Loss: 1.0433	Accuracy on validation set: 0.3750
# Epoch: 248	Loss: 1.0430	Accuracy on validation set: 0.3750
# Epoch: 249	Loss: 1.0428	Accuracy on validation set: 0.3750
# Epoch: 250	Loss: 1.0425	Accuracy on validation set: 0.3750
# Epoch: 251	Loss: 1.0423	Accuracy on validation set: 0.3750
# Epoch: 252	Loss: 1.0420	Accuracy on validation set: 0.4583
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 253	Loss: 1.0417	Accuracy on validation set: 0.4583
# Epoch: 254	Loss: 1.0415	Accuracy on validation set: 0.4583
# Epoch: 255	Loss: 1.0412	Accuracy on validation set: 0.4583
# Epoch: 256	Loss: 1.0410	Accuracy on validation set: 0.4583
# Epoch: 257	Loss: 1.0407	Accuracy on validation set: 0.4583
# Epoch: 258	Loss: 1.0404	Accuracy on validation set: 0.4583
# Epoch: 259	Loss: 1.0402	Accuracy on validation set: 0.5000
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 260	Loss: 1.0399	Accuracy on validation set: 0.5833
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 261	Loss: 1.0396	Accuracy on validation set: 0.5833
# Epoch: 262	Loss: 1.0394	Accuracy on validation set: 0.5833
# Epoch: 263	Loss: 1.0391	Accuracy on validation set: 0.5833
# Epoch: 264	Loss: 1.0388	Accuracy on validation set: 0.5833
# Epoch: 265	Loss: 1.0385	Accuracy on validation set: 0.5833
# Epoch: 266	Loss: 1.0382	Accuracy on validation set: 0.5833
# Epoch: 267	Loss: 1.0380	Accuracy on validation set: 0.5833
# Epoch: 268	Loss: 1.0377	Accuracy on validation set: 0.5833
# Epoch: 269	Loss: 1.0374	Accuracy on validation set: 0.5833
# Epoch: 270	Loss: 1.0371	Accuracy on validation set: 0.6250
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 271	Loss: 1.0368	Accuracy on validation set: 0.6250
# Epoch: 272	Loss: 1.0365	Accuracy on validation set: 0.6250
# Epoch: 273	Loss: 1.0363	Accuracy on validation set: 0.6667
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 274	Loss: 1.0360	Accuracy on validation set: 0.6667
# Epoch: 275	Loss: 1.0357	Accuracy on validation set: 0.6667
# Epoch: 276	Loss: 1.0354	Accuracy on validation set: 0.6667
# Epoch: 277	Loss: 1.0351	Accuracy on validation set: 0.7083
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 278	Loss: 1.0348	Accuracy on validation set: 0.7083
# Epoch: 279	Loss: 1.0345	Accuracy on validation set: 0.7083
# Epoch: 280	Loss: 1.0342	Accuracy on validation set: 0.7083
# Epoch: 281	Loss: 1.0339	Accuracy on validation set: 0.7083
# Epoch: 282	Loss: 1.0336	Accuracy on validation set: 0.7083
# Epoch: 283	Loss: 1.0333	Accuracy on validation set: 0.7083
# Epoch: 284	Loss: 1.0330	Accuracy on validation set: 0.7083
# Epoch: 285	Loss: 1.0327	Accuracy on validation set: 0.7083
# Epoch: 286	Loss: 1.0323	Accuracy on validation set: 0.7083
# Epoch: 287	Loss: 1.0320	Accuracy on validation set: 0.7083
# Epoch: 288	Loss: 1.0317	Accuracy on validation set: 0.7083
# Epoch: 289	Loss: 1.0314	Accuracy on validation set: 0.7083
# Epoch: 290	Loss: 1.0311	Accuracy on validation set: 0.7083
# Epoch: 291	Loss: 1.0308	Accuracy on validation set: 0.7083
# Epoch: 292	Loss: 1.0304	Accuracy on validation set: 0.7083
# Epoch: 293	Loss: 1.0301	Accuracy on validation set: 0.7083
# Epoch: 294	Loss: 1.0298	Accuracy on validation set: 0.7083
# Epoch: 295	Loss: 1.0295	Accuracy on validation set: 0.7083
# Epoch: 296	Loss: 1.0291	Accuracy on validation set: 0.7083
# Epoch: 297	Loss: 1.0288	Accuracy on validation set: 0.7083
# Epoch: 298	Loss: 1.0285	Accuracy on validation set: 0.7083
# Epoch: 299	Loss: 1.0281	Accuracy on validation set: 0.7083
# Epoch: 300	Loss: 1.0278	Accuracy on validation set: 0.7083
# Epoch: 301	Loss: 1.0275	Accuracy on validation set: 0.7083
# Epoch: 302	Loss: 1.0271	Accuracy on validation set: 0.7083
# Epoch: 303	Loss: 1.0268	Accuracy on validation set: 0.7083
# Epoch: 304	Loss: 1.0264	Accuracy on validation set: 0.7083
# Epoch: 305	Loss: 1.0261	Accuracy on validation set: 0.7083
# Epoch: 306	Loss: 1.0257	Accuracy on validation set: 0.7083
# Epoch: 307	Loss: 1.0254	Accuracy on validation set: 0.7083
# Epoch: 308	Loss: 1.0250	Accuracy on validation set: 0.7083
# Epoch: 309	Loss: 1.0247	Accuracy on validation set: 0.7083
# Epoch: 310	Loss: 1.0243	Accuracy on validation set: 0.7083
# Epoch: 311	Loss: 1.0240	Accuracy on validation set: 0.7083
# Epoch: 312	Loss: 1.0236	Accuracy on validation set: 0.7083
# Epoch: 313	Loss: 1.0232	Accuracy on validation set: 0.7083
# Epoch: 314	Loss: 1.0229	Accuracy on validation set: 0.7083
# Epoch: 315	Loss: 1.0225	Accuracy on validation set: 0.7083
# Epoch: 316	Loss: 1.0221	Accuracy on validation set: 0.7083
# Epoch: 317	Loss: 1.0218	Accuracy on validation set: 0.7083
# Epoch: 318	Loss: 1.0214	Accuracy on validation set: 0.7083
# Epoch: 319	Loss: 1.0210	Accuracy on validation set: 0.7083
# Epoch: 320	Loss: 1.0206	Accuracy on validation set: 0.7083
# Epoch: 321	Loss: 1.0202	Accuracy on validation set: 0.7083
# Epoch: 322	Loss: 1.0199	Accuracy on validation set: 0.7083
# Epoch: 323	Loss: 1.0195	Accuracy on validation set: 0.7083
# Epoch: 324	Loss: 1.0191	Accuracy on validation set: 0.7083
# Epoch: 325	Loss: 1.0187	Accuracy on validation set: 0.7083
# Epoch: 326	Loss: 1.0183	Accuracy on validation set: 0.7083
# Epoch: 327	Loss: 1.0179	Accuracy on validation set: 0.7083
# Epoch: 328	Loss: 1.0175	Accuracy on validation set: 0.7083
# Epoch: 329	Loss: 1.0171	Accuracy on validation set: 0.7083
# Epoch: 330	Loss: 1.0167	Accuracy on validation set: 0.7083
# Epoch: 331	Loss: 1.0163	Accuracy on validation set: 0.7083
# Epoch: 332	Loss: 1.0159	Accuracy on validation set: 0.7083
# Epoch: 333	Loss: 1.0155	Accuracy on validation set: 0.7083
# Epoch: 334	Loss: 1.0151	Accuracy on validation set: 0.7083
# Epoch: 335	Loss: 1.0147	Accuracy on validation set: 0.7083
# Epoch: 336	Loss: 1.0143	Accuracy on validation set: 0.7083
# Epoch: 337	Loss: 1.0138	Accuracy on validation set: 0.7083
# Epoch: 338	Loss: 1.0134	Accuracy on validation set: 0.7083
# Epoch: 339	Loss: 1.0130	Accuracy on validation set: 0.7083
# Epoch: 340	Loss: 1.0126	Accuracy on validation set: 0.7083
# Epoch: 341	Loss: 1.0122	Accuracy on validation set: 0.7083
# Epoch: 342	Loss: 1.0117	Accuracy on validation set: 0.7083
# Epoch: 343	Loss: 1.0113	Accuracy on validation set: 0.7083
# Epoch: 344	Loss: 1.0109	Accuracy on validation set: 0.7083
# Epoch: 345	Loss: 1.0104	Accuracy on validation set: 0.7083
# Epoch: 346	Loss: 1.0100	Accuracy on validation set: 0.7083
# Epoch: 347	Loss: 1.0095	Accuracy on validation set: 0.7083
# Epoch: 348	Loss: 1.0091	Accuracy on validation set: 0.7083
# Epoch: 349	Loss: 1.0087	Accuracy on validation set: 0.7083
# Epoch: 350	Loss: 1.0082	Accuracy on validation set: 0.7083
# Epoch: 351	Loss: 1.0077	Accuracy on validation set: 0.7083
# Epoch: 352	Loss: 1.0073	Accuracy on validation set: 0.7083
# Epoch: 353	Loss: 1.0068	Accuracy on validation set: 0.7083
# Epoch: 354	Loss: 1.0064	Accuracy on validation set: 0.7083
# Epoch: 355	Loss: 1.0059	Accuracy on validation set: 0.7083
# Epoch: 356	Loss: 1.0055	Accuracy on validation set: 0.7083
# Epoch: 357	Loss: 1.0050	Accuracy on validation set: 0.7083
# Epoch: 358	Loss: 1.0045	Accuracy on validation set: 0.7083
# Epoch: 359	Loss: 1.0040	Accuracy on validation set: 0.7083
# Epoch: 360	Loss: 1.0036	Accuracy on validation set: 0.7083
# Epoch: 361	Loss: 1.0031	Accuracy on validation set: 0.7083
# Epoch: 362	Loss: 1.0026	Accuracy on validation set: 0.7083
# Epoch: 363	Loss: 1.0021	Accuracy on validation set: 0.7083
# Epoch: 364	Loss: 1.0017	Accuracy on validation set: 0.7083
# Epoch: 365	Loss: 1.0012	Accuracy on validation set: 0.7083
# Epoch: 366	Loss: 1.0007	Accuracy on validation set: 0.7083
# Epoch: 367	Loss: 1.0002	Accuracy on validation set: 0.7083
# Epoch: 368	Loss: 0.9997	Accuracy on validation set: 0.7083
# Epoch: 369	Loss: 0.9992	Accuracy on validation set: 0.7083
# Epoch: 370	Loss: 0.9987	Accuracy on validation set: 0.7083
# Epoch: 371	Loss: 0.9982	Accuracy on validation set: 0.7083
# Epoch: 372	Loss: 0.9977	Accuracy on validation set: 0.7083
# Epoch: 373	Loss: 0.9972	Accuracy on validation set: 0.7083
# Epoch: 374	Loss: 0.9967	Accuracy on validation set: 0.7083
# Epoch: 375	Loss: 0.9962	Accuracy on validation set: 0.7083
# Epoch: 376	Loss: 0.9956	Accuracy on validation set: 0.7083
# Epoch: 377	Loss: 0.9951	Accuracy on validation set: 0.7083
# Epoch: 378	Loss: 0.9946	Accuracy on validation set: 0.7083
# Epoch: 379	Loss: 0.9941	Accuracy on validation set: 0.7083
# Epoch: 380	Loss: 0.9936	Accuracy on validation set: 0.7083
# Epoch: 381	Loss: 0.9930	Accuracy on validation set: 0.7083
# Epoch: 382	Loss: 0.9925	Accuracy on validation set: 0.7083
# Epoch: 383	Loss: 0.9920	Accuracy on validation set: 0.7083
# Epoch: 384	Loss: 0.9914	Accuracy on validation set: 0.7083
# Epoch: 516	Loss: 0.9092	Accuracy on validation set: 0.7083
# Epoch: 517	Loss: 0.9086	Accuracy on validation set: 0.7083
# Epoch: 518	Loss: 0.9080	Accuracy on validation set: 0.7083
# Epoch: 519	Loss: 0.9074	Accuracy on validation set: 0.7083
# Epoch: 520	Loss: 0.9068	Accuracy on validation set: 0.7083
# Epoch: 521	Loss: 0.9062	Accuracy on validation set: 0.7083
# Epoch: 522	Loss: 0.9056	Accuracy on validation set: 0.7083
# Epoch: 523	Loss: 0.9051	Accuracy on validation set: 0.7083
# Epoch: 524	Loss: 0.9045	Accuracy on validation set: 0.7083
# Epoch: 525	Loss: 0.9039	Accuracy on validation set: 0.7083
# Epoch: 526	Loss: 0.9033	Accuracy on validation set: 0.7083
# Epoch: 527	Loss: 0.9027	Accuracy on validation set: 0.7083
# Epoch: 528	Loss: 0.9022	Accuracy on validation set: 0.7083
# Epoch: 529	Loss: 0.9016	Accuracy on validation set: 0.7083
# Epoch: 530	Loss: 0.9010	Accuracy on validation set: 0.7083
# Epoch: 531	Loss: 0.9004	Accuracy on validation set: 0.7083
# Epoch: 532	Loss: 0.8999	Accuracy on validation set: 0.7083
# Epoch: 533	Loss: 0.8993	Accuracy on validation set: 0.7083
# Epoch: 534	Loss: 0.8987	Accuracy on validation set: 0.7083
# Epoch: 535	Loss: 0.8982	Accuracy on validation set: 0.7083
# Epoch: 536	Loss: 0.8976	Accuracy on validation set: 0.7083
# Epoch: 537	Loss: 0.8971	Accuracy on validation set: 0.7083
# Epoch: 538	Loss: 0.8965	Accuracy on validation set: 0.7083
# Epoch: 539	Loss: 0.8960	Accuracy on validation set: 0.7083
# Epoch: 540	Loss: 0.8954	Accuracy on validation set: 0.7083
# Epoch: 541	Loss: 0.8949	Accuracy on validation set: 0.7083
# Epoch: 542	Loss: 0.8943	Accuracy on validation set: 0.7083
# Epoch: 543	Loss: 0.8938	Accuracy on validation set: 0.7083
# Epoch: 544	Loss: 0.8932	Accuracy on validation set: 0.7083
# Epoch: 545	Loss: 0.8927	Accuracy on validation set: 0.7083
# Epoch: 546	Loss: 0.8922	Accuracy on validation set: 0.7083
# Epoch: 547	Loss: 0.8916	Accuracy on validation set: 0.7083
# Epoch: 548	Loss: 0.8911	Accuracy on validation set: 0.7083
# Epoch: 549	Loss: 0.8906	Accuracy on validation set: 0.7083
# Epoch: 550	Loss: 0.8900	Accuracy on validation set: 0.7083
# Epoch: 551	Loss: 0.8895	Accuracy on validation set: 0.7083
# Epoch: 552	Loss: 0.8890	Accuracy on validation set: 0.7083
# Epoch: 553	Loss: 0.8885	Accuracy on validation set: 0.7083
# Epoch: 554	Loss: 0.8880	Accuracy on validation set: 0.7083
# Epoch: 555	Loss: 0.8874	Accuracy on validation set: 0.7083
# Epoch: 556	Loss: 0.8869	Accuracy on validation set: 0.7083
# Epoch: 557	Loss: 0.8864	Accuracy on validation set: 0.7083
# Epoch: 558	Loss: 0.8859	Accuracy on validation set: 0.7083
# Epoch: 603	Loss: 0.8654	Accuracy on validation set: 0.7083
# Epoch: 604	Loss: 0.8650	Accuracy on validation set: 0.7083
# Epoch: 605	Loss: 0.8646	Accuracy on validation set: 0.7083
# Epoch: 606	Loss: 0.8642	Accuracy on validation set: 0.7083
# Epoch: 607	Loss: 0.8638	Accuracy on validation set: 0.7083
# Epoch: 608	Loss: 0.8634	Accuracy on validation set: 0.7083
# Epoch: 609	Loss: 0.8630	Accuracy on validation set: 0.7083
# Epoch: 610	Loss: 0.8626	Accuracy on validation set: 0.7083
# Epoch: 611	Loss: 0.8622	Accuracy on validation set: 0.7083
# Epoch: 612	Loss: 0.8619	Accuracy on validation set: 0.7083
# Epoch: 613	Loss: 0.8615	Accuracy on validation set: 0.7083
# Epoch: 614	Loss: 0.8611	Accuracy on validation set: 0.7083
# Epoch: 615	Loss: 0.8607	Accuracy on validation set: 0.7083
# Epoch: 616	Loss: 0.8603	Accuracy on validation set: 0.7083
# Epoch: 617	Loss: 0.8599	Accuracy on validation set: 0.7083
# Epoch: 618	Loss: 0.8596	Accuracy on validation set: 0.7083
# Epoch: 619	Loss: 0.8592	Accuracy on validation set: 0.7083
# Epoch: 620	Loss: 0.8588	Accuracy on validation set: 0.7083
# Epoch: 621	Loss: 0.8584	Accuracy on validation set: 0.7083
# Epoch: 622	Loss: 0.8581	Accuracy on validation set: 0.7083
# Epoch: 623	Loss: 0.8577	Accuracy on validation set: 0.7083
# Epoch: 624	Loss: 0.8573	Accuracy on validation set: 0.7083
# Epoch: 625	Loss: 0.8569	Accuracy on validation set: 0.7083
# Epoch: 626	Loss: 0.8566	Accuracy on validation set: 0.7083
# Epoch: 627	Loss: 0.8562	Accuracy on validation set: 0.7083
# Epoch: 628	Loss: 0.8559	Accuracy on validation set: 0.7083
# Epoch: 629	Loss: 0.8555	Accuracy on validation set: 0.7083
# Epoch: 630	Loss: 0.8551	Accuracy on validation set: 0.7083
# Epoch: 631	Loss: 0.8548	Accuracy on validation set: 0.7083
# Epoch: 632	Loss: 0.8544	Accuracy on validation set: 0.7083
# Epoch: 633	Loss: 0.8541	Accuracy on validation set: 0.7083
# Epoch: 634	Loss: 0.8537	Accuracy on validation set: 0.7083
# Epoch: 635	Loss: 0.8534	Accuracy on validation set: 0.7083
# Epoch: 636	Loss: 0.8530	Accuracy on validation set: 0.7083
# Epoch: 637	Loss: 0.8527	Accuracy on validation set: 0.7083
# Epoch: 638	Loss: 0.8523	Accuracy on validation set: 0.7083
# Epoch: 639	Loss: 0.8520	Accuracy on validation set: 0.7083
# Epoch: 640	Loss: 0.8516	Accuracy on validation set: 0.7083
# Epoch: 641	Loss: 0.8513	Accuracy on validation set: 0.7083
# Epoch: 642	Loss: 0.8509	Accuracy on validation set: 0.7083
# Epoch: 643	Loss: 0.8506	Accuracy on validation set: 0.7083
# Epoch: 644	Loss: 0.8502	Accuracy on validation set: 0.7083
# Epoch: 645	Loss: 0.8499	Accuracy on validation set: 0.7083
# Epoch: 646	Loss: 0.8496	Accuracy on validation set: 0.7083
# Epoch: 690	Loss: 0.8359	Accuracy on validation set: 0.7083
# Epoch: 691	Loss: 0.8356	Accuracy on validation set: 0.7083
# Epoch: 692	Loss: 0.8354	Accuracy on validation set: 0.7083
# Epoch: 693	Loss: 0.8351	Accuracy on validation set: 0.7083
# Epoch: 694	Loss: 0.8348	Accuracy on validation set: 0.7083
# Epoch: 695	Loss: 0.8345	Accuracy on validation set: 0.7083
# Epoch: 696	Loss: 0.8342	Accuracy on validation set: 0.7083
# Epoch: 697	Loss: 0.8339	Accuracy on validation set: 0.7083
# Epoch: 698	Loss: 0.8337	Accuracy on validation set: 0.7083
# Epoch: 699	Loss: 0.8334	Accuracy on validation set: 0.7083
# Epoch: 700	Loss: 0.8331	Accuracy on validation set: 0.7083
# Epoch: 701	Loss: 0.8328	Accuracy on validation set: 0.7083
# Epoch: 702	Loss: 0.8326	Accuracy on validation set: 0.7083
# Epoch: 703	Loss: 0.8323	Accuracy on validation set: 0.7083
# Epoch: 704	Loss: 0.8320	Accuracy on validation set: 0.7083
# Epoch: 705	Loss: 0.8317	Accuracy on validation set: 0.7083
# Epoch: 706	Loss: 0.8315	Accuracy on validation set: 0.7083
# Epoch: 707	Loss: 0.8312	Accuracy on validation set: 0.7083
# Epoch: 708	Loss: 0.8309	Accuracy on validation set: 0.7083
# Epoch: 709	Loss: 0.8307	Accuracy on validation set: 0.7083
# Epoch: 710	Loss: 0.8304	Accuracy on validation set: 0.7083
# Epoch: 711	Loss: 0.8301	Accuracy on validation set: 0.7083
# Epoch: 712	Loss: 0.8299	Accuracy on validation set: 0.7083
# Epoch: 713	Loss: 0.8296	Accuracy on validation set: 0.7083
# Epoch: 714	Loss: 0.8293	Accuracy on validation set: 0.7083
# Epoch: 715	Loss: 0.8291	Accuracy on validation set: 0.7083
# Epoch: 716	Loss: 0.8288	Accuracy on validation set: 0.7083
# Epoch: 717	Loss: 0.8285	Accuracy on validation set: 0.7083
# Epoch: 718	Loss: 0.8283	Accuracy on validation set: 0.7083
# Epoch: 719	Loss: 0.8280	Accuracy on validation set: 0.7083
# Epoch: 720	Loss: 0.8278	Accuracy on validation set: 0.7083
# Epoch: 721	Loss: 0.8275	Accuracy on validation set: 0.7083
# Epoch: 722	Loss: 0.8272	Accuracy on validation set: 0.7083
# Epoch: 723	Loss: 0.8270	Accuracy on validation set: 0.7083
# Epoch: 724	Loss: 0.8267	Accuracy on validation set: 0.7083
# Epoch: 725	Loss: 0.8265	Accuracy on validation set: 0.7083
# Epoch: 726	Loss: 0.8262	Accuracy on validation set: 0.7083
# Epoch: 727	Loss: 0.8260	Accuracy on validation set: 0.7083
# Epoch: 728	Loss: 0.8257	Accuracy on validation set: 0.7083
# Epoch: 729	Loss: 0.8255	Accuracy on validation set: 0.7083
# Epoch: 730	Loss: 0.8252	Accuracy on validation set: 0.7083
# Epoch: 731	Loss: 0.8250	Accuracy on validation set: 0.7083
# Epoch: 732	Loss: 0.8247	Accuracy on validation set: 0.7083
# Epoch: 733	Loss: 0.8245	Accuracy on validation set: 0.7083
# Epoch: 778	Loss: 0.8137	Accuracy on validation set: 0.7083
# Epoch: 779	Loss: 0.8135	Accuracy on validation set: 0.7083
# Epoch: 780	Loss: 0.8133	Accuracy on validation set: 0.7083
# Epoch: 781	Loss: 0.8131	Accuracy on validation set: 0.7083
# Epoch: 782	Loss: 0.8128	Accuracy on validation set: 0.7083
# Epoch: 783	Loss: 0.8126	Accuracy on validation set: 0.7083
# Epoch: 784	Loss: 0.8124	Accuracy on validation set: 0.7083
# Epoch: 785	Loss: 0.8121	Accuracy on validation set: 0.7083
# Epoch: 786	Loss: 0.8119	Accuracy on validation set: 0.7083
# Epoch: 787	Loss: 0.8117	Accuracy on validation set: 0.7083
# Epoch: 788	Loss: 0.8115	Accuracy on validation set: 0.7083
# Epoch: 789	Loss: 0.8112	Accuracy on validation set: 0.7083
# Epoch: 790	Loss: 0.8110	Accuracy on validation set: 0.7083
# Epoch: 791	Loss: 0.8108	Accuracy on validation set: 0.7083
# Epoch: 792	Loss: 0.8106	Accuracy on validation set: 0.7083
# Epoch: 793	Loss: 0.8104	Accuracy on validation set: 0.7083
# Epoch: 794	Loss: 0.8101	Accuracy on validation set: 0.7083
# Epoch: 795	Loss: 0.8099	Accuracy on validation set: 0.7083
# Epoch: 796	Loss: 0.8097	Accuracy on validation set: 0.7083
# Epoch: 797	Loss: 0.8095	Accuracy on validation set: 0.7083
# Epoch: 798	Loss: 0.8092	Accuracy on validation set: 0.7083
# Epoch: 799	Loss: 0.8090	Accuracy on validation set: 0.7083
# Epoch: 800	Loss: 0.8088	Accuracy on validation set: 0.7083
# Epoch: 801	Loss: 0.8086	Accuracy on validation set: 0.7083
# ...
# Epoch: 2446	Loss: 0.5953	Accuracy on validation set: 0.9583
# Epoch: 2447	Loss: 0.5953	Accuracy on validation set: 0.9583
# Epoch: 2448	Loss: 0.5952	Accuracy on validation set: 0.9583
# Epoch: 2449	Loss: 0.5952	Accuracy on validation set: 0.9583
# Epoch: 2450	Loss: 0.5952	Accuracy on validation set: 0.9583
# Epoch: 2451	Loss: 0.5951	Accuracy on validation set: 0.9583
# Epoch: 2452	Loss: 0.5951	Accuracy on validation set: 0.9583
# Epoch: 2453	Loss: 0.5951	Accuracy on validation set: 0.9583
# Epoch: 2454	Loss: 0.5951	Accuracy on validation set: 0.9583
# Epoch: 2455	Loss: 0.5950	Accuracy on validation set: 0.9583
# Epoch: 2456	Loss: 0.5950	Accuracy on validation set: 0.9583
# Epoch: 2457	Loss: 0.5950	Accuracy on validation set: 0.9583
# Epoch: 2458	Loss: 0.5949	Accuracy on validation set: 0.9583
# Epoch: 2459	Loss: 0.5949	Accuracy on validation set: 0.9583
# Epoch: 2460	Loss: 0.5949	Accuracy on validation set: 0.9583
# Epoch: 2461	Loss: 0.5949	Accuracy on validation set: 0.9583
# Epoch: 2462	Loss: 0.5948	Accuracy on validation set: 0.9583
# Epoch: 2463	Loss: 0.5948	Accuracy on validation set: 0.9583
# Epoch: 2464	Loss: 0.5948	Accuracy on validation set: 0.9583
# Epoch: 2465	Loss: 0.5947	Accuracy on validation set: 0.9583
# Epoch: 2466	Loss: 0.5947	Accuracy on validation set: 0.9583
# Epoch: 2467	Loss: 0.5947	Accuracy on validation set: 0.9583
# Epoch: 2468	Loss: 0.5947	Accuracy on validation set: 0.9583
# Epoch: 2469	Loss: 0.5946	Accuracy on validation set: 0.9583
# Epoch: 2470	Loss: 0.5946	Accuracy on validation set: 0.9583
# Epoch: 2471	Loss: 0.5946	Accuracy on validation set: 0.9583
# Epoch: 2472	Loss: 0.5945	Accuracy on validation set: 0.9583
# Epoch: 2473	Loss: 0.5945	Accuracy on validation set: 0.9583
# Epoch: 2474	Loss: 0.5945	Accuracy on validation set: 0.9583
# Epoch: 2475	Loss: 0.5945	Accuracy on validation set: 0.9583
# Epoch: 2476	Loss: 0.5944	Accuracy on validation set: 0.9583
# Epoch: 2477	Loss: 0.5944	Accuracy on validation set: 0.9583
# Epoch: 2478	Loss: 0.5944	Accuracy on validation set: 0.9583
# Epoch: 2479	Loss: 0.5944	Accuracy on validation set: 0.9583
# Epoch: 2480	Loss: 0.5943	Accuracy on validation set: 0.9583
# Epoch: 2481	Loss: 0.5943	Accuracy on validation set: 0.9583
# Epoch: 2482	Loss: 0.5943	Accuracy on validation set: 0.9583
# Epoch: 2483	Loss: 0.5942	Accuracy on validation set: 0.9583
# Epoch: 2484	Loss: 0.5942	Accuracy on validation set: 0.9583
# Epoch: 2485	Loss: 0.5942	Accuracy on validation set: 0.9583
# Epoch: 2486	Loss: 0.5942	Accuracy on validation set: 0.9583
# Epoch: 2487	Loss: 0.5941	Accuracy on validation set: 0.9583
# Epoch: 2488	Loss: 0.5941	Accuracy on validation set: 0.9583
# Epoch: 2489	Loss: 0.5941	Accuracy on validation set: 0.9583
# Epoch: 2490	Loss: 0.5941	Accuracy on validation set: 0.9583
# Epoch: 2491	Loss: 0.5940	Accuracy on validation set: 0.9583
# Epoch: 2492	Loss: 0.5940	Accuracy on validation set: 0.9583
# Epoch: 2493	Loss: 0.5940	Accuracy on validation set: 0.9583
# Epoch: 2494	Loss: 0.5939	Accuracy on validation set: 0.9583
# Epoch: 2495	Loss: 0.5939	Accuracy on validation set: 0.9583
# Epoch: 2496	Loss: 0.5939	Accuracy on validation set: 0.9583
# Epoch: 2497	Loss: 0.5939	Accuracy on validation set: 0.9583
# Epoch: 2498	Loss: 0.5938	Accuracy on validation set: 0.9583
# Epoch: 2499	Loss: 0.5938	Accuracy on validation set: 0.9583
# Epoch: 2500	Loss: 0.5938	Accuracy on validation set: 0.9583
# Epoch: 2501	Loss: 0.5938	Accuracy on validation set: 0.9583
# Epoch: 2502	Loss: 0.5937	Accuracy on validation set: 0.9583
# Epoch: 2503	Loss: 0.5937	Accuracy on validation set: 0.9583
# Epoch: 2504	Loss: 0.5937	Accuracy on validation set: 0.9583
# Epoch: 2505	Loss: 0.5937	Accuracy on validation set: 0.9583
# Epoch: 2506	Loss: 0.5936	Accuracy on validation set: 0.9583
# Epoch: 2507	Loss: 0.5936	Accuracy on validation set: 0.9583
# Epoch: 2508	Loss: 0.5936	Accuracy on validation set: 0.9583
# Epoch: 2509	Loss: 0.5935	Accuracy on validation set: 0.9583
# Epoch: 2510	Loss: 0.5935	Accuracy on validation set: 0.9583
# Epoch: 2511	Loss: 0.5935	Accuracy on validation set: 0.9583
# Epoch: 2512	Loss: 0.5935	Accuracy on validation set: 0.9583
# Epoch: 2513	Loss: 0.5934	Accuracy on validation set: 0.9583
# Epoch: 2514	Loss: 0.5934	Accuracy on validation set: 0.9583
# Epoch: 2515	Loss: 0.5934	Accuracy on validation set: 0.9583
# Epoch: 2516	Loss: 0.5934	Accuracy on validation set: 0.9583
# Epoch: 2517	Loss: 0.5933	Accuracy on validation set: 0.9583
# Epoch: 2518	Loss: 0.5933	Accuracy on validation set: 0.9583
# Epoch: 2519	Loss: 0.5933	Accuracy on validation set: 0.9583
# Epoch: 2520	Loss: 0.5933	Accuracy on validation set: 0.9583
# Epoch: 2521	Loss: 0.5932	Accuracy on validation set: 0.9583
# Epoch: 2522	Loss: 0.5932	Accuracy on validation set: 0.9583
# Epoch: 2523	Loss: 0.5932	Accuracy on validation set: 0.9583
# Epoch: 2524	Loss: 0.5932	Accuracy on validation set: 0.9583
# Epoch: 2525	Loss: 0.5931	Accuracy on validation set: 0.9583
# Epoch: 2526	Loss: 0.5931	Accuracy on validation set: 0.9583
# Epoch: 2527	Loss: 0.5931	Accuracy on validation set: 0.9583
# Epoch: 2528	Loss: 0.5931	Accuracy on validation set: 0.9583
# Epoch: 2529	Loss: 0.5930	Accuracy on validation set: 0.9583
# Epoch: 2530	Loss: 0.5930	Accuracy on validation set: 0.9583
# Epoch: 2531	Loss: 0.5930	Accuracy on validation set: 0.9583
# Epoch: 2532	Loss: 0.5929	Accuracy on validation set: 0.9583
# Epoch: 2533	Loss: 0.5929	Accuracy on validation set: 0.9583
# Epoch: 2534	Loss: 0.5929	Accuracy on validation set: 0.9583
# Epoch: 2535	Loss: 0.5929	Accuracy on validation set: 0.9583
# Epoch: 2536	Loss: 0.5928	Accuracy on validation set: 0.9583
# Epoch: 2537	Loss: 0.5928	Accuracy on validation set: 0.9583
# Epoch: 2538	Loss: 0.5928	Accuracy on validation set: 0.9583
# Epoch: 2539	Loss: 0.5928	Accuracy on validation set: 0.9583
# Epoch: 2540	Loss: 0.5927	Accuracy on validation set: 0.9583
# Epoch: 2541	Loss: 0.5927	Accuracy on validation set: 0.9583
# Epoch: 2542	Loss: 0.5927	Accuracy on validation set: 0.9583
# Epoch: 2543	Loss: 0.5927	Accuracy on validation set: 0.9583
# Epoch: 2544	Loss: 0.5926	Accuracy on validation set: 0.9583
# Epoch: 2545	Loss: 0.5926	Accuracy on validation set: 0.9583
# Epoch: 2546	Loss: 0.5926	Accuracy on validation set: 0.9583
# Epoch: 2547	Loss: 0.5926	Accuracy on validation set: 0.9583
# Epoch: 2548	Loss: 0.5925	Accuracy on validation set: 0.9583
# Epoch: 2549	Loss: 0.5925	Accuracy on validation set: 0.9583
# Epoch: 2550	Loss: 0.5925	Accuracy on validation set: 0.9583
# Epoch: 2551	Loss: 0.5925	Accuracy on validation set: 0.9583
# Epoch: 2552	Loss: 0.5924	Accuracy on validation set: 0.9583
# Epoch: 2553	Loss: 0.5924	Accuracy on validation set: 0.9583
# Epoch: 2554	Loss: 0.5924	Accuracy on validation set: 0.9583
# Epoch: 2555	Loss: 0.5924	Accuracy on validation set: 0.9583
# Epoch: 2556	Loss: 0.5923	Accuracy on validation set: 0.9583
# Epoch: 2557	Loss: 0.5923	Accuracy on validation set: 0.9583
# Epoch: 2558	Loss: 0.5923	Accuracy on validation set: 0.9583
# Epoch: 2559	Loss: 0.5923	Accuracy on validation set: 0.9583
# Epoch: 2560	Loss: 0.5922	Accuracy on validation set: 0.9583
# Epoch: 2561	Loss: 0.5922	Accuracy on validation set: 0.9583
# Epoch: 2562	Loss: 0.5922	Accuracy on validation set: 0.9583
# Epoch: 2563	Loss: 0.5922	Accuracy on validation set: 0.9583
# Epoch: 2564	Loss: 0.5921	Accuracy on validation set: 0.9583
# Epoch: 2565	Loss: 0.5921	Accuracy on validation set: 0.9583
# Epoch: 2566	Loss: 0.5921	Accuracy on validation set: 0.9583
# Epoch: 2567	Loss: 0.5921	Accuracy on validation set: 0.9583
# Epoch: 2568	Loss: 0.5921	Accuracy on validation set: 0.9583
# Epoch: 2569	Loss: 0.5920	Accuracy on validation set: 0.9583
# Epoch: 2570	Loss: 0.5920	Accuracy on validation set: 0.9583
# Epoch: 2571	Loss: 0.5920	Accuracy on validation set: 0.9583
# Epoch: 2572	Loss: 0.5920	Accuracy on validation set: 0.9583
# Epoch: 2573	Loss: 0.5919	Accuracy on validation set: 0.9583
# Epoch: 2574	Loss: 0.5919	Accuracy on validation set: 0.9583
# Epoch: 2575	Loss: 0.5919	Accuracy on validation set: 0.9583
# Epoch: 2576	Loss: 0.5919	Accuracy on validation set: 0.9583
# Epoch: 2577	Loss: 0.5918	Accuracy on validation set: 0.9583
# Epoch: 2578	Loss: 0.5918	Accuracy on validation set: 0.9583
# Epoch: 2579	Loss: 0.5918	Accuracy on validation set: 0.9583
# Epoch: 2580	Loss: 0.5918	Accuracy on validation set: 0.9583
# Epoch: 2581	Loss: 0.5917	Accuracy on validation set: 0.9583
# Epoch: 2582	Loss: 0.5917	Accuracy on validation set: 0.9583
# Epoch: 2583	Loss: 0.5917	Accuracy on validation set: 0.9583
# Epoch: 2584	Loss: 0.5917	Accuracy on validation set: 0.9583
# Epoch: 2585	Loss: 0.5916	Accuracy on validation set: 0.9583
# Epoch: 2586	Loss: 0.5916	Accuracy on validation set: 0.9583
# Epoch: 2587	Loss: 0.5916	Accuracy on validation set: 0.9583
# Epoch: 2588	Loss: 0.5916	Accuracy on validation set: 0.9583
# Epoch: 2589	Loss: 0.5915	Accuracy on validation set: 0.9583
# Epoch: 2590	Loss: 0.5915	Accuracy on validation set: 0.9583
# Epoch: 2591	Loss: 0.5915	Accuracy on validation set: 0.9583
# Epoch: 2592	Loss: 0.5915	Accuracy on validation set: 0.9583
# Epoch: 2593	Loss: 0.5915	Accuracy on validation set: 0.9583
# Epoch: 2594	Loss: 0.5914	Accuracy on validation set: 0.9583
# Epoch: 2595	Loss: 0.5914	Accuracy on validation set: 0.9583
# Epoch: 2596	Loss: 0.5914	Accuracy on validation set: 0.9583
# Epoch: 2597	Loss: 0.5914	Accuracy on validation set: 0.9583
# Epoch: 2598	Loss: 0.5913	Accuracy on validation set: 0.9583
# Epoch: 2599	Loss: 0.5913	Accuracy on validation set: 0.9583
# Epoch: 2600	Loss: 0.5913	Accuracy on validation set: 0.9583
# Epoch: 2601	Loss: 0.5913	Accuracy on validation set: 0.9583
# Epoch: 2602	Loss: 0.5912	Accuracy on validation set: 0.9583
# Epoch: 2603	Loss: 0.5912	Accuracy on validation set: 0.9583
# Epoch: 2604	Loss: 0.5912	Accuracy on validation set: 0.9583
# Epoch: 2605	Loss: 0.5912	Accuracy on validation set: 0.9583
# Epoch: 2606	Loss: 0.5912	Accuracy on validation set: 0.9583
# Epoch: 2607	Loss: 0.5911	Accuracy on validation set: 0.9583
# Epoch: 2608	Loss: 0.5911	Accuracy on validation set: 0.9583
# Epoch: 2609	Loss: 0.5911	Accuracy on validation set: 0.9583
# Epoch: 2610	Loss: 0.5911	Accuracy on validation set: 0.9583
# Epoch: 2611	Loss: 0.5910	Accuracy on validation set: 0.9583
# Epoch: 2612	Loss: 0.5910	Accuracy on validation set: 0.9583
# Epoch: 2613	Loss: 0.5910	Accuracy on validation set: 0.9583
# Epoch: 2614	Loss: 0.5910	Accuracy on validation set: 0.9583
# Epoch: 2615	Loss: 0.5909	Accuracy on validation set: 0.9583
# Epoch: 2616	Loss: 0.5909	Accuracy on validation set: 0.9583
# Epoch: 2617	Loss: 0.5909	Accuracy on validation set: 0.9583
# Epoch: 2618	Loss: 0.5909	Accuracy on validation set: 0.9583
# Epoch: 2619	Loss: 0.5909	Accuracy on validation set: 0.9583
# Epoch: 2620	Loss: 0.5908	Accuracy on validation set: 0.9583
# Epoch: 2621	Loss: 0.5908	Accuracy on validation set: 0.9583
# Epoch: 2622	Loss: 0.5908	Accuracy on validation set: 0.9583
# Epoch: 2623	Loss: 0.5908	Accuracy on validation set: 0.9583
# Epoch: 2624	Loss: 0.5907	Accuracy on validation set: 0.9583
# Epoch: 2625	Loss: 0.5907	Accuracy on validation set: 0.9583
# Epoch: 2626	Loss: 0.5907	Accuracy on validation set: 0.9583
# Epoch: 2627	Loss: 0.5907	Accuracy on validation set: 0.9583
# Epoch: 2628	Loss: 0.5906	Accuracy on validation set: 0.9583
# Epoch: 2629	Loss: 0.5906	Accuracy on validation set: 0.9583
# Epoch: 2630	Loss: 0.5906	Accuracy on validation set: 0.9583
# Epoch: 2631	Loss: 0.5906	Accuracy on validation set: 0.9583
# Epoch: 2632	Loss: 0.5906	Accuracy on validation set: 0.9583
# Epoch: 2633	Loss: 0.5905	Accuracy on validation set: 0.9583
# Epoch: 2634	Loss: 0.5905	Accuracy on validation set: 0.9583
# Epoch: 2635	Loss: 0.5905	Accuracy on validation set: 0.9583
# Epoch: 2636	Loss: 0.5905	Accuracy on validation set: 0.9583
# Epoch: 2637	Loss: 0.5904	Accuracy on validation set: 0.9583
# Epoch: 2638	Loss: 0.5904	Accuracy on validation set: 0.9583
# Epoch: 2639	Loss: 0.5904	Accuracy on validation set: 0.9583
# Epoch: 2640	Loss: 0.5904	Accuracy on validation set: 0.9583
# Epoch: 2641	Loss: 0.5904	Accuracy on validation set: 0.9583
# Epoch: 2642	Loss: 0.5903	Accuracy on validation set: 0.9583
# Epoch: 2643	Loss: 0.5903	Accuracy on validation set: 0.9583
# Epoch: 2644	Loss: 0.5903	Accuracy on validation set: 0.9583
# Epoch: 2645	Loss: 0.5903	Accuracy on validation set: 0.9583
# Epoch: 2646	Loss: 0.5902	Accuracy on validation set: 0.9583
# Epoch: 2647	Loss: 0.5902	Accuracy on validation set: 0.9583
# Epoch: 2648	Loss: 0.5902	Accuracy on validation set: 0.9583
# Epoch: 2649	Loss: 0.5902	Accuracy on validation set: 0.9583
# Epoch: 2650	Loss: 0.5902	Accuracy on validation set: 0.9583
# Epoch: 2651	Loss: 0.5901	Accuracy on validation set: 0.9583
# Epoch: 2652	Loss: 0.5901	Accuracy on validation set: 0.9583
# Epoch: 2653	Loss: 0.5901	Accuracy on validation set: 0.9583
# Epoch: 2654	Loss: 0.5901	Accuracy on validation set: 0.9583
# Epoch: 2655	Loss: 0.5901	Accuracy on validation set: 0.9583
# Epoch: 2656	Loss: 0.5900	Accuracy on validation set: 0.9583
# Epoch: 2657	Loss: 0.5900	Accuracy on validation set: 0.9583
# Epoch: 2658	Loss: 0.5900	Accuracy on validation set: 0.9583
# Epoch: 2659	Loss: 0.5900	Accuracy on validation set: 0.9583
# Epoch: 2660	Loss: 0.5899	Accuracy on validation set: 0.9583
# Epoch: 2661	Loss: 0.5899	Accuracy on validation set: 0.9583
# Epoch: 2662	Loss: 0.5899	Accuracy on validation set: 0.9583
# Epoch: 2663	Loss: 0.5899	Accuracy on validation set: 0.9583
# Epoch: 2664	Loss: 0.5899	Accuracy on validation set: 0.9583
# Epoch: 2665	Loss: 0.5898	Accuracy on validation set: 0.9583
# Epoch: 2666	Loss: 0.5898	Accuracy on validation set: 0.9583
# Epoch: 2667	Loss: 0.5898	Accuracy on validation set: 0.9583
# Epoch: 2668	Loss: 0.5898	Accuracy on validation set: 0.9583
# Epoch: 2669	Loss: 0.5898	Accuracy on validation set: 0.9583
# Epoch: 2670	Loss: 0.5897	Accuracy on validation set: 0.9583
# Epoch: 2671	Loss: 0.5897	Accuracy on validation set: 0.9583
# Epoch: 2672	Loss: 0.5897	Accuracy on validation set: 0.9583
# Epoch: 2673	Loss: 0.5897	Accuracy on validation set: 0.9583
# Epoch: 2674	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2675	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2676	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2677	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2678	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2679	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2680	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2681	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2682	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2683	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2684	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2685	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2686	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2687	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2688	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2689	Loss: 0.5893	Accuracy on validation set: 0.9583
# Epoch: 2690	Loss: 0.5893	Accuracy on validation set: 0.9583
# Epoch: 2691	Loss: 0.5893	Accuracy on validation set: 0.9583
# Epoch: 2692	Loss: 0.5893	Accuracy on validation set: 0.9583
# Epoch: 2693	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2694	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2695	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2696	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2697	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2698	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2699	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2700	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2701	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2702	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2703	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2704	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2705	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2706	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2707	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2708	Loss: 0.5889	Accuracy on validation set: 0.9583
# Epoch: 2709	Loss: 0.5889	Accuracy on validation set: 0.9583
# Epoch: 2710	Loss: 0.5889	Accuracy on validation set: 0.9583
# Epoch: 2711	Loss: 0.5889	Accuracy on validation set: 0.9583
# Early stopping!

# %% [markdown]
# Finally, use the model (whether newly trained from scratch or trained previously and imported) to make predictions on the unseen test set.

# %%
# predict output of test data
Y_predict = model(X_test)
_, labels = torch.max(Y_predict, 1)
accuracy_score(labels, Y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# *Tip:* Seldomly, the model does not perform well. Run the training cell again, choosing not to load the saved model. This will give you extra training epochs on the already trained model and the loss should continue to decrease. If necessary, do this over and over again until the model performs well. Otherwise, you can also start from scratch and hope for better initialization of the weights and biases.
