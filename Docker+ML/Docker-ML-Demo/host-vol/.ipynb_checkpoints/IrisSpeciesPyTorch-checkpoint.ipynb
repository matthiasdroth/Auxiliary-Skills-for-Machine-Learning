# %% [markdown]
# # Iris Species Classification with PyTorch
# For details, see also
# - https://github.com/pratibhashinde/Project-Iris-PyTorch/blob/master/iris_pytorch.ipynb (primary code source),
# - https://pytorch.org/tutorials/beginner/saving_loading_models.html (on saving and loading pytorch models), and
# - ddd (docker tutorial to which this notebook belongs).
#
# Start by importing required libraries and the iris dataset from the *iris.csv* file. Of course, the iris dataset could also be imported via `from sklearn.datasets import load_iris` but within the docker tutorial (see third link above), we also want to demonstrate the usage of **volumes** that make files on the host (like *iris.csv*) available to a program inside a running docker container (like this jupyter notebook).

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import path
from sklearn.metrics import accuracy_score
np.random.seed(7)
# load and display data
df = pd.read_csv('iris.csv')
print(df)
# converting name (=species) labels to 0, 1, 2
df.loc[df.Name=='Iris-setosa', 'Name'] = 0
df.loc[df.Name=='Iris-versicolor', 'Name'] = 1
df.loc[df.Name=='Iris-virginica', 'Name'] = 2
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]
#      SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0            5.1         3.5          1.4         0.2    0
# 1            4.9         3.0          1.4         0.2    0
# 2            4.7         3.2          1.3         0.2    0
# 3            4.6         3.1          1.5         0.2    0
# 4            5.0         3.6          1.4         0.2    0
# ..           ...         ...          ...         ...  ...
# 145          6.7         3.0          5.2         2.3    2
# 146          6.3         2.5          5.0         1.9    2
# 147          6.5         3.0          5.2         2.0    2
# 148          6.2         3.4          5.4         2.3    2
# 149          5.9         3.0          5.1         1.8    2
#
# [150 rows x 5 columns]

# %% [markdown]
# We have imported the data and converted the iris species *iris-setosa*, *iris-versicolor*, and *iris-virginica* to integer values 0, 1, and 2, respectively. Now, we split the dataset into features X and labels Y, shuffle the instances, and divide it into subsets for training, validation, and testing.

# %%
split_ratio = 0.8
X = df[df.columns[0:4]].values
Y = df[df.columns[4]].values.astype(int)
shuffle_indices = np.random.permutation(len(Y))
print(shuffle_indices[:10])
X , Y = X[shuffle_indices], Y[shuffle_indices]
print(len(Y))
split_1 = int(np.round(split_ratio * len(Y)))
split_2 = int(np.round(split_ratio * split_1))
X, X_test = X[:split_1], X[split_1:]
Y, Y_test = Y[:split_1], Y[split_1:]
print(len(X), len(X_test))
print(len(Y), len(Y_test))
print(split_1)
X, X_valid = X[:split_2], X[split_2:]
Y, Y_valid = Y[:split_2], Y[split_2:]
print(len(X), len(X_valid))
print(len(Y), len(Y_valid))
X[:10], Y[:10]
# Out:
# [149  84  40  66 106  41  52  94  11  51]
# 150
# 120 30
# 120 30
# 120
# 96 24
# 96 24
# (array([[5.9, 3. , 5.1, 1.8],
#         [5.4, 3. , 4.5, 1.5],
#         [5. , 3.5, 1.3, 0.3],
#         [5.6, 3. , 4.5, 1.5],
#         [4.9, 2.5, 4.5, 1.7],
#         [4.5, 2.3, 1.3, 0.3],
#         [6.9, 3.1, 4.9, 1.5],
#         [5.6, 2.7, 4.2, 1.3],
#         [4.8, 3.4, 1.6, 0.2],
#         [6.4, 3.2, 4.5, 1.5]]),
#  array([2, 1, 0, 1, 2, 0, 1, 1, 0, 1]))

# %% [markdown]
# Since the iris dataset does not have many instances (namely 150) to start with, we need to make sure that classes are similarly represented in all subsets (training, validation, and testing).

# %%
def checkClasses(y):
    counts = [0, 0, 0]
    for i in range(len(y)):
        counts[y[i]] += 1
    return counts
checkClasses(Y), checkClasses(Y_valid), checkClasses(Y_test)
# Out:
# ([32, 31, 33], [9, 7, 8], [9, 12, 9])

# %% [markdown]
# We are pretty much done with preparing the dataset and now turn to the neural net. First of all, we convert the input data into tensor format. Then, we define a class for a fully connected neural net and instatiate a net with two hidden layers where each of them has 6 neurons. As demanded by the three different classes, the output layer has three neurons that feed into a softmax activation function. We also define a filepath for saving the model.

# %%
X, Y = torch.Tensor(X).float(), torch.Tensor(Y)
X_valid, Y_valid = torch.Tensor(X_valid).float(), torch.Tensor(Y_valid)
X_test, Y_test = torch.Tensor(X_test).float(), torch.Tensor(Y_test)
# define model class
class net(nn.Module):
    def __init__(self, hidden_1, hidden_2):
        super(net, self).__init__()
        self.f1 = nn.Linear(4, hidden_1)
        self.a1 = nn.ReLU()
        self.f2 = nn.Linear(hidden_1, hidden_2)
        self.f3 = nn.Linear(hidden_2, 3)
        self.softmax = nn.Softmax(dim=1)
    def forward(self, x):
        x = self.f1(x)
        x = self.a1(x)
        x = self.f2(x)
        x = self.f3(x)
        x = self.softmax(x)
        return x
# build model instance and define the path for the saved model
model = net(6, 6)
model_path = './iris_model.pth'

# %% [markdown]
# If there exists a saved model file from a previous training run, we can choose to load it and skip training. If such file does not exist or we choose not to load it the model will be trained and a model file will be created.
#
# The main point here is not so much the training but the **creation of a file** (namely the file of the trained and saved model) that persists in the docker volume **beyond the lifetime of the docker container**. And it goes both ways: after stopping the container and starting a new one from the same image (while also mounting the same volume), the saved model file will still be available from inside the new docker container.

# %%
train = 1
# check for a saved model file from a previous training run
if path.exists(model_path):
    # if a model has been saved, decide whether to load it or not
    answer = input('Load the pretrained model? [0=no, everything else=yes] ')
    if answer!='0':
        train = 0
# if there is a pretrained model AND it shall be loaded, then do load it ...
if train==0:
    model.load_state_dict(torch.load(model_path))
    print('The pretrained model has been loaded.')
# ... otherwise, train the model from scratch (and save the trained model)
else:
    print('Training the model ...')
    # loss and optimizer
    loss_fn = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01)
    # train the model
    epochs = 5000
    losses = []
    valid_accs = []
    max_valid_acc = 0
    stagnation_count = 0
    stagnation_threshold = 1500
    for epoch in range(epochs):
        # predictions, loss, gradient, gradient step
        Y_pred = model(X)
        loss = loss_fn(Y_pred, Y.long())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # accuracy on validation set
        Y_valid_logits = model(X_valid)
        _, Y_valid_pred = torch.max(Y_valid_logits, 1)
        valid_acc = accuracy_score(Y_valid_pred, Y_valid)
        # log loss and accuracy
        losses.append(loss.item())
        valid_accs.append(valid_acc)
        # print output
        print('Epoch: {:d}\tLoss: {:.4f}\tAccuracy on validation set: {:.4f}'.format(epoch, loss.item(), valid_acc))
        # early stopping
        if valid_acc > max_valid_acc:
            #torch.save(model, model_path)
            torch.save(model.state_dict(), model_path)
            max_valid_acc = valid_acc
            stagnation_count = 0
            print('Accuracy on validation set has just improved!')
            print ('The model has been saved under ' + model_path + '.')
        else:
            stagnation_count += 1
            if stagnation_count > stagnation_threshold:
                print('Early stopping!')
                break
    # make a nice plot showing the loss (on training set) and the accuary (on validation set) over epochs
    fig, ax1 = plt.subplots()
    color1 = 'tab:red'
    ax1.set_xlabel('epochs')
    ax1.set_ylabel('loss (training set)', color=color1)
    ax1.plot(losses, color=color1)
    ax1.tick_params(axis='y', labelcolor=color1)
    ax2 = ax1.twinx()
    color2 = 'tab:blue'
    ax2.set_ylabel('accuracy (validation set)', color=color2)
    ax2.plot(valid_accs, color=color2)
    ax2.tick_params(axis='y', labelcolor=color2)
    fig.tight_layout()
    plt.show()
# Out:
# Training the model ...
# Epoch: 0	Loss: 1.0933	Accuracy on validation set: 0.2917
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 1	Loss: 1.0928	Accuracy on validation set: 0.2917
# Epoch: 2	Loss: 1.0923	Accuracy on validation set: 0.2917
# Epoch: 3	Loss: 1.0919	Accuracy on validation set: 0.2917
# Epoch: 4	Loss: 1.0914	Accuracy on validation set: 0.2917
# Epoch: 5	Loss: 1.0909	Accuracy on validation set: 0.2917
# Epoch: 6	Loss: 1.0905	Accuracy on validation set: 0.2917
# Epoch: 7	Loss: 1.0900	Accuracy on validation set: 0.2917
# Epoch: 8	Loss: 1.0896	Accuracy on validation set: 0.2917
# Epoch: 9	Loss: 1.0891	Accuracy on validation set: 0.2917
# Epoch: 10	Loss: 1.0886	Accuracy on validation set: 0.2917
# Epoch: 11	Loss: 1.0882	Accuracy on validation set: 0.2917
# Epoch: 12	Loss: 1.0877	Accuracy on validation set: 0.2917
# Epoch: 13	Loss: 1.0873	Accuracy on validation set: 0.2917
# Epoch: 14	Loss: 1.0868	Accuracy on validation set: 0.2917
# Epoch: 15	Loss: 1.0864	Accuracy on validation set: 0.2917
# Epoch: 16	Loss: 1.0859	Accuracy on validation set: 0.2917
# Epoch: 17	Loss: 1.0855	Accuracy on validation set: 0.2917
# Epoch: 18	Loss: 1.0850	Accuracy on validation set: 0.2917
# Epoch: 19	Loss: 1.0846	Accuracy on validation set: 0.2917
# Epoch: 20	Loss: 1.0841	Accuracy on validation set: 0.2917
# Epoch: 21	Loss: 1.0837	Accuracy on validation set: 0.2917
# Epoch: 22	Loss: 1.0833	Accuracy on validation set: 0.2917
# Epoch: 23	Loss: 1.0828	Accuracy on validation set: 0.2917
# Epoch: 24	Loss: 1.0824	Accuracy on validation set: 0.2917
# Epoch: 25	Loss: 1.0820	Accuracy on validation set: 0.3333
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 26	Loss: 1.0816	Accuracy on validation set: 0.3333
# Epoch: 27	Loss: 1.0811	Accuracy on validation set: 0.3333
# Epoch: 28	Loss: 1.0807	Accuracy on validation set: 0.3750
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 29	Loss: 1.0803	Accuracy on validation set: 0.5000
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 30	Loss: 1.0799	Accuracy on validation set: 0.5000
# Epoch: 31	Loss: 1.0795	Accuracy on validation set: 0.5417
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 32	Loss: 1.0791	Accuracy on validation set: 0.5417
# Epoch: 33	Loss: 1.0786	Accuracy on validation set: 0.5417
# Epoch: 34	Loss: 1.0782	Accuracy on validation set: 0.5000
# Epoch: 35	Loss: 1.0778	Accuracy on validation set: 0.5000
# Epoch: 36	Loss: 1.0774	Accuracy on validation set: 0.5417
# Epoch: 37	Loss: 1.0771	Accuracy on validation set: 0.5417
# Epoch: 38	Loss: 1.0767	Accuracy on validation set: 0.5417
# Epoch: 39	Loss: 1.0763	Accuracy on validation set: 0.5417
# Epoch: 40	Loss: 1.0759	Accuracy on validation set: 0.5417
# Epoch: 41	Loss: 1.0755	Accuracy on validation set: 0.4583
# Epoch: 42	Loss: 1.0751	Accuracy on validation set: 0.4583
# Epoch: 43	Loss: 1.0748	Accuracy on validation set: 0.4583
# Epoch: 44	Loss: 1.0744	Accuracy on validation set: 0.4167
# Epoch: 45	Loss: 1.0740	Accuracy on validation set: 0.4167
# Epoch: 46	Loss: 1.0737	Accuracy on validation set: 0.3750
# Epoch: 47	Loss: 1.0733	Accuracy on validation set: 0.3750
# Epoch: 48	Loss: 1.0730	Accuracy on validation set: 0.3750
# Epoch: 49	Loss: 1.0726	Accuracy on validation set: 0.3750
# Epoch: 50	Loss: 1.0723	Accuracy on validation set: 0.3750
# Epoch: 51	Loss: 1.0719	Accuracy on validation set: 0.3750
# Epoch: 52	Loss: 1.0716	Accuracy on validation set: 0.3750
# Epoch: 53	Loss: 1.0713	Accuracy on validation set: 0.3333
# Epoch: 54	Loss: 1.0709	Accuracy on validation set: 0.3333
# Epoch: 55	Loss: 1.0706	Accuracy on validation set: 0.3333
# Epoch: 56	Loss: 1.0703	Accuracy on validation set: 0.3333
# Epoch: 57	Loss: 1.0700	Accuracy on validation set: 0.3333
# Epoch: 58	Loss: 1.0696	Accuracy on validation set: 0.3333
# Epoch: 59	Loss: 1.0693	Accuracy on validation set: 0.3333
# Epoch: 60	Loss: 1.0690	Accuracy on validation set: 0.3333
# Epoch: 61	Loss: 1.0687	Accuracy on validation set: 0.3333
# Epoch: 62	Loss: 1.0684	Accuracy on validation set: 0.3333
# Epoch: 63	Loss: 1.0681	Accuracy on validation set: 0.3333
# Epoch: 64	Loss: 1.0678	Accuracy on validation set: 0.3333
# Epoch: 65	Loss: 1.0675	Accuracy on validation set: 0.3333
# Epoch: 66	Loss: 1.0672	Accuracy on validation set: 0.3333
# Epoch: 67	Loss: 1.0669	Accuracy on validation set: 0.3333
# Epoch: 68	Loss: 1.0667	Accuracy on validation set: 0.3333
# Epoch: 69	Loss: 1.0664	Accuracy on validation set: 0.3333
# Epoch: 70	Loss: 1.0661	Accuracy on validation set: 0.3333
# Epoch: 71	Loss: 1.0658	Accuracy on validation set: 0.3333
# Epoch: 72	Loss: 1.0656	Accuracy on validation set: 0.3333
# Epoch: 73	Loss: 1.0653	Accuracy on validation set: 0.3333
# Epoch: 74	Loss: 1.0650	Accuracy on validation set: 0.3333
# Epoch: 75	Loss: 1.0648	Accuracy on validation set: 0.3333
# Epoch: 76	Loss: 1.0645	Accuracy on validation set: 0.3333
# Epoch: 77	Loss: 1.0642	Accuracy on validation set: 0.3333
# Epoch: 78	Loss: 1.0640	Accuracy on validation set: 0.3333
# Epoch: 79	Loss: 1.0637	Accuracy on validation set: 0.3333
# Epoch: 80	Loss: 1.0635	Accuracy on validation set: 0.3333
# Epoch: 81	Loss: 1.0632	Accuracy on validation set: 0.3333
# Epoch: 82	Loss: 1.0630	Accuracy on validation set: 0.3333
# Epoch: 83	Loss: 1.0627	Accuracy on validation set: 0.3333
# Epoch: 84	Loss: 1.0625	Accuracy on validation set: 0.3333
# Epoch: 85	Loss: 1.0623	Accuracy on validation set: 0.3333
# Epoch: 86	Loss: 1.0620	Accuracy on validation set: 0.3333
# Epoch: 87	Loss: 1.0618	Accuracy on validation set: 0.3333
# Epoch: 88	Loss: 1.0615	Accuracy on validation set: 0.3333
# Epoch: 89	Loss: 1.0613	Accuracy on validation set: 0.3333
# Epoch: 90	Loss: 1.0611	Accuracy on validation set: 0.3333
# Epoch: 91	Loss: 1.0609	Accuracy on validation set: 0.3333
# Epoch: 92	Loss: 1.0606	Accuracy on validation set: 0.3333
# Epoch: 93	Loss: 1.0604	Accuracy on validation set: 0.3333
# Epoch: 94	Loss: 1.0602	Accuracy on validation set: 0.3333
# Epoch: 95	Loss: 1.0599	Accuracy on validation set: 0.3333
# Epoch: 96	Loss: 1.0597	Accuracy on validation set: 0.3333
# Epoch: 97	Loss: 1.0595	Accuracy on validation set: 0.3333
# Epoch: 98	Loss: 1.0593	Accuracy on validation set: 0.3333
# Epoch: 99	Loss: 1.0591	Accuracy on validation set: 0.3333
# Epoch: 100	Loss: 1.0588	Accuracy on validation set: 0.3333
# Epoch: 101	Loss: 1.0586	Accuracy on validation set: 0.3333
# Epoch: 102	Loss: 1.0584	Accuracy on validation set: 0.3333
# Epoch: 103	Loss: 1.0582	Accuracy on validation set: 0.3333
# Epoch: 104	Loss: 1.0580	Accuracy on validation set: 0.3333
# Epoch: 105	Loss: 1.0578	Accuracy on validation set: 0.3333
# Epoch: 106	Loss: 1.0575	Accuracy on validation set: 0.3333
# Epoch: 107	Loss: 1.0573	Accuracy on validation set: 0.3333
# Epoch: 108	Loss: 1.0571	Accuracy on validation set: 0.3333
# Epoch: 109	Loss: 1.0569	Accuracy on validation set: 0.3333
# Epoch: 110	Loss: 1.0567	Accuracy on validation set: 0.3333
# Epoch: 111	Loss: 1.0565	Accuracy on validation set: 0.3333
# Epoch: 112	Loss: 1.0563	Accuracy on validation set: 0.3333
# Epoch: 113	Loss: 1.0560	Accuracy on validation set: 0.3333
# Epoch: 114	Loss: 1.0558	Accuracy on validation set: 0.3333
# Epoch: 115	Loss: 1.0556	Accuracy on validation set: 0.3333
# Epoch: 116	Loss: 1.0554	Accuracy on validation set: 0.3333
# Epoch: 117	Loss: 1.0552	Accuracy on validation set: 0.3333
# Epoch: 118	Loss: 1.0550	Accuracy on validation set: 0.3333
# Epoch: 119	Loss: 1.0548	Accuracy on validation set: 0.3333
# Epoch: 120	Loss: 1.0546	Accuracy on validation set: 0.3333
# Epoch: 121	Loss: 1.0543	Accuracy on validation set: 0.3333
# Epoch: 122	Loss: 1.0541	Accuracy on validation set: 0.3333
# Epoch: 123	Loss: 1.0539	Accuracy on validation set: 0.3333
# Epoch: 124	Loss: 1.0537	Accuracy on validation set: 0.3333
# Epoch: 125	Loss: 1.0535	Accuracy on validation set: 0.3333
# Epoch: 126	Loss: 1.0533	Accuracy on validation set: 0.3333
# Epoch: 127	Loss: 1.0531	Accuracy on validation set: 0.3333
# Epoch: 128	Loss: 1.0529	Accuracy on validation set: 0.3333
# Epoch: 129	Loss: 1.0526	Accuracy on validation set: 0.3333
# Epoch: 130	Loss: 1.0524	Accuracy on validation set: 0.3333
# Epoch: 131	Loss: 1.0522	Accuracy on validation set: 0.3333
# Epoch: 132	Loss: 1.0520	Accuracy on validation set: 0.3333
# Epoch: 133	Loss: 1.0518	Accuracy on validation set: 0.3333
# Epoch: 134	Loss: 1.0516	Accuracy on validation set: 0.3333
# Epoch: 135	Loss: 1.0514	Accuracy on validation set: 0.3333
# Epoch: 136	Loss: 1.0511	Accuracy on validation set: 0.3333
# Epoch: 137	Loss: 1.0509	Accuracy on validation set: 0.3333
# Epoch: 138	Loss: 1.0507	Accuracy on validation set: 0.3333
# Epoch: 139	Loss: 1.0505	Accuracy on validation set: 0.3333
# Epoch: 140	Loss: 1.0503	Accuracy on validation set: 0.3333
# Epoch: 141	Loss: 1.0500	Accuracy on validation set: 0.3333
# Epoch: 142	Loss: 1.0498	Accuracy on validation set: 0.3333
# Epoch: 143	Loss: 1.0496	Accuracy on validation set: 0.3333
# Epoch: 144	Loss: 1.0494	Accuracy on validation set: 0.3333
# Epoch: 145	Loss: 1.0492	Accuracy on validation set: 0.3333
# Epoch: 146	Loss: 1.0489	Accuracy on validation set: 0.3333
# Epoch: 147	Loss: 1.0487	Accuracy on validation set: 0.3333
# Epoch: 148	Loss: 1.0485	Accuracy on validation set: 0.3333
# Epoch: 149	Loss: 1.0483	Accuracy on validation set: 0.3333
# Epoch: 150	Loss: 1.0480	Accuracy on validation set: 0.3333
# Epoch: 151	Loss: 1.0478	Accuracy on validation set: 0.3333
# Epoch: 152	Loss: 1.0476	Accuracy on validation set: 0.3333
# Epoch: 153	Loss: 1.0473	Accuracy on validation set: 0.3333
# Epoch: 154	Loss: 1.0471	Accuracy on validation set: 0.3333
# Epoch: 155	Loss: 1.0469	Accuracy on validation set: 0.3333
# Epoch: 156	Loss: 1.0467	Accuracy on validation set: 0.3333
# Epoch: 157	Loss: 1.0464	Accuracy on validation set: 0.3333
# Epoch: 158	Loss: 1.0462	Accuracy on validation set: 0.3333
# Epoch: 159	Loss: 1.0459	Accuracy on validation set: 0.3333
# Epoch: 160	Loss: 1.0457	Accuracy on validation set: 0.3333
# Epoch: 161	Loss: 1.0455	Accuracy on validation set: 0.3333
# Epoch: 162	Loss: 1.0452	Accuracy on validation set: 0.3333
# Epoch: 163	Loss: 1.0450	Accuracy on validation set: 0.3333
# Epoch: 164	Loss: 1.0448	Accuracy on validation set: 0.3333
# Epoch: 165	Loss: 1.0445	Accuracy on validation set: 0.3333
# Epoch: 166	Loss: 1.0443	Accuracy on validation set: 0.3333
# Epoch: 167	Loss: 1.0440	Accuracy on validation set: 0.3333
# Epoch: 168	Loss: 1.0438	Accuracy on validation set: 0.3333
# Epoch: 169	Loss: 1.0436	Accuracy on validation set: 0.3333
# Epoch: 170	Loss: 1.0433	Accuracy on validation set: 0.3333
# Epoch: 171	Loss: 1.0431	Accuracy on validation set: 0.3333
# Epoch: 172	Loss: 1.0428	Accuracy on validation set: 0.3333
# Epoch: 173	Loss: 1.0426	Accuracy on validation set: 0.3333
# Epoch: 174	Loss: 1.0423	Accuracy on validation set: 0.3333
# Epoch: 175	Loss: 1.0421	Accuracy on validation set: 0.3333
# Epoch: 176	Loss: 1.0418	Accuracy on validation set: 0.3333
# Epoch: 177	Loss: 1.0416	Accuracy on validation set: 0.3333
# Epoch: 178	Loss: 1.0413	Accuracy on validation set: 0.3333
# Epoch: 179	Loss: 1.0410	Accuracy on validation set: 0.3333
# Epoch: 180	Loss: 1.0408	Accuracy on validation set: 0.3333
# Epoch: 181	Loss: 1.0405	Accuracy on validation set: 0.3333
# Epoch: 182	Loss: 1.0403	Accuracy on validation set: 0.3333
# Epoch: 183	Loss: 1.0400	Accuracy on validation set: 0.3333
# Epoch: 184	Loss: 1.0397	Accuracy on validation set: 0.3333
# Epoch: 185	Loss: 1.0395	Accuracy on validation set: 0.3333
# Epoch: 186	Loss: 1.0392	Accuracy on validation set: 0.3333
# Epoch: 187	Loss: 1.0390	Accuracy on validation set: 0.3333
# Epoch: 188	Loss: 1.0387	Accuracy on validation set: 0.3333
# Epoch: 189	Loss: 1.0384	Accuracy on validation set: 0.3333
# Epoch: 190	Loss: 1.0381	Accuracy on validation set: 0.3333
# Epoch: 191	Loss: 1.0379	Accuracy on validation set: 0.3333
# Epoch: 192	Loss: 1.0376	Accuracy on validation set: 0.3333
# Epoch: 193	Loss: 1.0373	Accuracy on validation set: 0.3333
# Epoch: 194	Loss: 1.0371	Accuracy on validation set: 0.3333
# Epoch: 195	Loss: 1.0368	Accuracy on validation set: 0.3333
# Epoch: 196	Loss: 1.0365	Accuracy on validation set: 0.3333
# Epoch: 197	Loss: 1.0362	Accuracy on validation set: 0.3333
# Epoch: 198	Loss: 1.0359	Accuracy on validation set: 0.3333
# Epoch: 199	Loss: 1.0357	Accuracy on validation set: 0.3333
# Epoch: 200	Loss: 1.0354	Accuracy on validation set: 0.3333
# Epoch: 201	Loss: 1.0351	Accuracy on validation set: 0.3333
# Epoch: 202	Loss: 1.0348	Accuracy on validation set: 0.3333
# Epoch: 203	Loss: 1.0345	Accuracy on validation set: 0.3333
# Epoch: 204	Loss: 1.0342	Accuracy on validation set: 0.3333
# Epoch: 205	Loss: 1.0339	Accuracy on validation set: 0.3333
# Epoch: 206	Loss: 1.0337	Accuracy on validation set: 0.3333
# Epoch: 207	Loss: 1.0334	Accuracy on validation set: 0.3333
# Epoch: 208	Loss: 1.0331	Accuracy on validation set: 0.3333
# Epoch: 209	Loss: 1.0328	Accuracy on validation set: 0.3333
# Epoch: 210	Loss: 1.0325	Accuracy on validation set: 0.3333
# Epoch: 211	Loss: 1.0322	Accuracy on validation set: 0.3333
# Epoch: 212	Loss: 1.0319	Accuracy on validation set: 0.3333
# Epoch: 213	Loss: 1.0316	Accuracy on validation set: 0.3333
# Epoch: 214	Loss: 1.0313	Accuracy on validation set: 0.3333
# Epoch: 215	Loss: 1.0310	Accuracy on validation set: 0.3333
# Epoch: 216	Loss: 1.0307	Accuracy on validation set: 0.3333
# Epoch: 217	Loss: 1.0303	Accuracy on validation set: 0.3333
# Epoch: 218	Loss: 1.0300	Accuracy on validation set: 0.3333
# Epoch: 219	Loss: 1.0297	Accuracy on validation set: 0.3333
# Epoch: 220	Loss: 1.0294	Accuracy on validation set: 0.3333
# Epoch: 221	Loss: 1.0291	Accuracy on validation set: 0.3333
# Epoch: 222	Loss: 1.0288	Accuracy on validation set: 0.3333
# Epoch: 223	Loss: 1.0285	Accuracy on validation set: 0.3333
# Epoch: 224	Loss: 1.0281	Accuracy on validation set: 0.3333
# Epoch: 225	Loss: 1.0278	Accuracy on validation set: 0.3333
# Epoch: 226	Loss: 1.0275	Accuracy on validation set: 0.3333
# Epoch: 227	Loss: 1.0272	Accuracy on validation set: 0.3333
# Epoch: 228	Loss: 1.0269	Accuracy on validation set: 0.3333
# Epoch: 229	Loss: 1.0265	Accuracy on validation set: 0.3333
# Epoch: 230	Loss: 1.0262	Accuracy on validation set: 0.3333
# Epoch: 231	Loss: 1.0259	Accuracy on validation set: 0.3333
# Epoch: 232	Loss: 1.0255	Accuracy on validation set: 0.3333
# Epoch: 233	Loss: 1.0252	Accuracy on validation set: 0.3333
# Epoch: 234	Loss: 1.0249	Accuracy on validation set: 0.3333
# Epoch: 235	Loss: 1.0245	Accuracy on validation set: 0.3333
# Epoch: 236	Loss: 1.0242	Accuracy on validation set: 0.3333
# Epoch: 237	Loss: 1.0238	Accuracy on validation set: 0.3333
# Epoch: 238	Loss: 1.0235	Accuracy on validation set: 0.3333
# Epoch: 239	Loss: 1.0232	Accuracy on validation set: 0.3333
# Epoch: 240	Loss: 1.0228	Accuracy on validation set: 0.3333
# Epoch: 241	Loss: 1.0225	Accuracy on validation set: 0.3333
# Epoch: 242	Loss: 1.0221	Accuracy on validation set: 0.3333
# Epoch: 243	Loss: 1.0218	Accuracy on validation set: 0.3333
# Epoch: 244	Loss: 1.0214	Accuracy on validation set: 0.3333
# Epoch: 245	Loss: 1.0210	Accuracy on validation set: 0.3333
# Epoch: 246	Loss: 1.0207	Accuracy on validation set: 0.3333
# Epoch: 247	Loss: 1.0203	Accuracy on validation set: 0.3333
# Epoch: 248	Loss: 1.0200	Accuracy on validation set: 0.3333
# Epoch: 249	Loss: 1.0196	Accuracy on validation set: 0.3333
# Epoch: 250	Loss: 1.0192	Accuracy on validation set: 0.3333
# Epoch: 251	Loss: 1.0189	Accuracy on validation set: 0.3333
# Epoch: 252	Loss: 1.0185	Accuracy on validation set: 0.3333
# Epoch: 253	Loss: 1.0181	Accuracy on validation set: 0.3333
# Epoch: 254	Loss: 1.0178	Accuracy on validation set: 0.3333
# Epoch: 255	Loss: 1.0174	Accuracy on validation set: 0.3333
# Epoch: 256	Loss: 1.0170	Accuracy on validation set: 0.3333
# Epoch: 257	Loss: 1.0166	Accuracy on validation set: 0.3333
# Epoch: 258	Loss: 1.0163	Accuracy on validation set: 0.3333
# Epoch: 259	Loss: 1.0159	Accuracy on validation set: 0.3333
# Epoch: 260	Loss: 1.0155	Accuracy on validation set: 0.3333
# Epoch: 261	Loss: 1.0151	Accuracy on validation set: 0.3333
# Epoch: 262	Loss: 1.0147	Accuracy on validation set: 0.3333
# Epoch: 263	Loss: 1.0143	Accuracy on validation set: 0.3333
# Epoch: 264	Loss: 1.0139	Accuracy on validation set: 0.3333
# Epoch: 265	Loss: 1.0135	Accuracy on validation set: 0.3333
# Epoch: 266	Loss: 1.0131	Accuracy on validation set: 0.3333
# Epoch: 267	Loss: 1.0127	Accuracy on validation set: 0.3333
# Epoch: 268	Loss: 1.0123	Accuracy on validation set: 0.3750
# Epoch: 269	Loss: 1.0119	Accuracy on validation set: 0.3750
# Epoch: 270	Loss: 1.0115	Accuracy on validation set: 0.3750
# Epoch: 271	Loss: 1.0111	Accuracy on validation set: 0.4167
# Epoch: 272	Loss: 1.0107	Accuracy on validation set: 0.4167
# Epoch: 273	Loss: 1.0103	Accuracy on validation set: 0.5000
# Epoch: 274	Loss: 1.0099	Accuracy on validation set: 0.5417
# Epoch: 275	Loss: 1.0095	Accuracy on validation set: 0.5833
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 276	Loss: 1.0090	Accuracy on validation set: 0.5833
# Epoch: 277	Loss: 1.0086	Accuracy on validation set: 0.5833
# Epoch: 278	Loss: 1.0082	Accuracy on validation set: 0.6250
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 279	Loss: 1.0078	Accuracy on validation set: 0.7083
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 280	Loss: 1.0074	Accuracy on validation set: 0.7083
# Epoch: 281	Loss: 1.0069	Accuracy on validation set: 0.7083
# Epoch: 282	Loss: 1.0065	Accuracy on validation set: 0.7083
# Epoch: 283	Loss: 1.0061	Accuracy on validation set: 0.7083
# Epoch: 284	Loss: 1.0056	Accuracy on validation set: 0.7083
# Epoch: 285	Loss: 1.0052	Accuracy on validation set: 0.7083
# Epoch: 286	Loss: 1.0047	Accuracy on validation set: 0.7083
# Epoch: 287	Loss: 1.0043	Accuracy on validation set: 0.7083
# Epoch: 288	Loss: 1.0039	Accuracy on validation set: 0.7083
# Epoch: 289	Loss: 1.0034	Accuracy on validation set: 0.7083
# Epoch: 290	Loss: 1.0030	Accuracy on validation set: 0.7083
# Epoch: 291	Loss: 1.0025	Accuracy on validation set: 0.7083
# Epoch: 292	Loss: 1.0021	Accuracy on validation set: 0.7083
# Epoch: 293	Loss: 1.0016	Accuracy on validation set: 0.7083
# Epoch: 294	Loss: 1.0011	Accuracy on validation set: 0.7083
# Epoch: 295	Loss: 1.0007	Accuracy on validation set: 0.7083
# Epoch: 296	Loss: 1.0002	Accuracy on validation set: 0.7083
# Epoch: 297	Loss: 0.9998	Accuracy on validation set: 0.7083
# Epoch: 298	Loss: 0.9993	Accuracy on validation set: 0.7083
# Epoch: 299	Loss: 0.9988	Accuracy on validation set: 0.7083
# Epoch: 300	Loss: 0.9983	Accuracy on validation set: 0.7083
# Epoch: 301	Loss: 0.9979	Accuracy on validation set: 0.7083
# Epoch: 302	Loss: 0.9974	Accuracy on validation set: 0.7083
# Epoch: 303	Loss: 0.9969	Accuracy on validation set: 0.7083
# Epoch: 304	Loss: 0.9964	Accuracy on validation set: 0.7083
# Epoch: 305	Loss: 0.9959	Accuracy on validation set: 0.7083
# Epoch: 306	Loss: 0.9955	Accuracy on validation set: 0.7083
# Epoch: 307	Loss: 0.9950	Accuracy on validation set: 0.7083
# Epoch: 308	Loss: 0.9945	Accuracy on validation set: 0.7083
# Epoch: 309	Loss: 0.9940	Accuracy on validation set: 0.7083
# Epoch: 310	Loss: 0.9935	Accuracy on validation set: 0.7083
# Epoch: 311	Loss: 0.9930	Accuracy on validation set: 0.7083
# Epoch: 312	Loss: 0.9925	Accuracy on validation set: 0.7083
# Epoch: 313	Loss: 0.9920	Accuracy on validation set: 0.7083
# Epoch: 314	Loss: 0.9915	Accuracy on validation set: 0.7083
# Epoch: 315	Loss: 0.9910	Accuracy on validation set: 0.7083
# Epoch: 316	Loss: 0.9905	Accuracy on validation set: 0.7083
# Epoch: 317	Loss: 0.9899	Accuracy on validation set: 0.7083
# Epoch: 318	Loss: 0.9894	Accuracy on validation set: 0.7083
# Epoch: 319	Loss: 0.9889	Accuracy on validation set: 0.7083
# Epoch: 320	Loss: 0.9884	Accuracy on validation set: 0.7083
# Epoch: 321	Loss: 0.9879	Accuracy on validation set: 0.7083
# Epoch: 322	Loss: 0.9873	Accuracy on validation set: 0.7083
# Epoch: 323	Loss: 0.9868	Accuracy on validation set: 0.7083
# Epoch: 324	Loss: 0.9863	Accuracy on validation set: 0.7083
# Epoch: 325	Loss: 0.9858	Accuracy on validation set: 0.7083
# Epoch: 326	Loss: 0.9852	Accuracy on validation set: 0.7083
# Epoch: 327	Loss: 0.9847	Accuracy on validation set: 0.7083
# Epoch: 328	Loss: 0.9841	Accuracy on validation set: 0.7083
# Epoch: 329	Loss: 0.9836	Accuracy on validation set: 0.7083
# Epoch: 330	Loss: 0.9831	Accuracy on validation set: 0.7083
# Epoch: 595	Loss: 0.8330	Accuracy on validation set: 0.7083
# Epoch: 596	Loss: 0.8326	Accuracy on validation set: 0.7083
# Epoch: 597	Loss: 0.8323	Accuracy on validation set: 0.7083
# Epoch: 598	Loss: 0.8319	Accuracy on validation set: 0.7083
# Epoch: 599	Loss: 0.8315	Accuracy on validation set: 0.7083
# Epoch: 600	Loss: 0.8311	Accuracy on validation set: 0.7083
# Epoch: 601	Loss: 0.8308	Accuracy on validation set: 0.7083
# Epoch: 602	Loss: 0.8304	Accuracy on validation set: 0.7083
# Epoch: 603	Loss: 0.8300	Accuracy on validation set: 0.7083
# Epoch: 604	Loss: 0.8297	Accuracy on validation set: 0.7083
# Epoch: 605	Loss: 0.8293	Accuracy on validation set: 0.7083
# Epoch: 606	Loss: 0.8290	Accuracy on validation set: 0.7083
# Epoch: 607	Loss: 0.8286	Accuracy on validation set: 0.7083
# Epoch: 608	Loss: 0.8282	Accuracy on validation set: 0.7083
# Epoch: 609	Loss: 0.8279	Accuracy on validation set: 0.7083
# Epoch: 610	Loss: 0.8275	Accuracy on validation set: 0.7083
# Epoch: 611	Loss: 0.8272	Accuracy on validation set: 0.7083
# Epoch: 612	Loss: 0.8268	Accuracy on validation set: 0.7083
# Epoch: 613	Loss: 0.8265	Accuracy on validation set: 0.7083
# Epoch: 614	Loss: 0.8261	Accuracy on validation set: 0.7083
# Epoch: 615	Loss: 0.8258	Accuracy on validation set: 0.7083
# Epoch: 616	Loss: 0.8254	Accuracy on validation set: 0.7083
# Epoch: 617	Loss: 0.8251	Accuracy on validation set: 0.7083
# Epoch: 618	Loss: 0.8247	Accuracy on validation set: 0.7083
# Epoch: 619	Loss: 0.8244	Accuracy on validation set: 0.7083
# Epoch: 620	Loss: 0.8240	Accuracy on validation set: 0.7083
# Epoch: 621	Loss: 0.8237	Accuracy on validation set: 0.7083
# Epoch: 622	Loss: 0.8233	Accuracy on validation set: 0.7083
# Epoch: 623	Loss: 0.8230	Accuracy on validation set: 0.7083
# Epoch: 624	Loss: 0.8226	Accuracy on validation set: 0.7083
# Epoch: 625	Loss: 0.8223	Accuracy on validation set: 0.7083
# Epoch: 626	Loss: 0.8219	Accuracy on validation set: 0.7083
# Epoch: 627	Loss: 0.8216	Accuracy on validation set: 0.7083
# Epoch: 628	Loss: 0.8213	Accuracy on validation set: 0.7083
# Epoch: 629	Loss: 0.8209	Accuracy on validation set: 0.7083
# Epoch: 630	Loss: 0.8206	Accuracy on validation set: 0.7083
# Epoch: 631	Loss: 0.8203	Accuracy on validation set: 0.7083
# Epoch: 632	Loss: 0.8199	Accuracy on validation set: 0.7083
# Epoch: 633	Loss: 0.8196	Accuracy on validation set: 0.7083
# Epoch: 634	Loss: 0.8193	Accuracy on validation set: 0.7083
# Epoch: 635	Loss: 0.8189	Accuracy on validation set: 0.7083
# Epoch: 636	Loss: 0.8186	Accuracy on validation set: 0.7083
# Epoch: 637	Loss: 0.8183	Accuracy on validation set: 0.7083
# Epoch: 638	Loss: 0.8179	Accuracy on validation set: 0.7083
# Epoch: 727	Loss: 0.7907	Accuracy on validation set: 0.7500
# Epoch: 728	Loss: 0.7904	Accuracy on validation set: 0.7500
# Epoch: 729	Loss: 0.7902	Accuracy on validation set: 0.7500
# Epoch: 730	Loss: 0.7899	Accuracy on validation set: 0.7500
# Epoch: 731	Loss: 0.7896	Accuracy on validation set: 0.7500
# Epoch: 732	Loss: 0.7893	Accuracy on validation set: 0.7500
# Epoch: 733	Loss: 0.7890	Accuracy on validation set: 0.7500
# Epoch: 734	Loss: 0.7887	Accuracy on validation set: 0.7917
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 735	Loss: 0.7884	Accuracy on validation set: 0.7917
# Epoch: 736	Loss: 0.7881	Accuracy on validation set: 0.7917
# Epoch: 737	Loss: 0.7879	Accuracy on validation set: 0.7917
# Epoch: 738	Loss: 0.7876	Accuracy on validation set: 0.7917
# Epoch: 739	Loss: 0.7873	Accuracy on validation set: 0.7917
# Epoch: 740	Loss: 0.7870	Accuracy on validation set: 0.7917
# Epoch: 741	Loss: 0.7867	Accuracy on validation set: 0.7917
# Epoch: 742	Loss: 0.7864	Accuracy on validation set: 0.7917
# Epoch: 743	Loss: 0.7861	Accuracy on validation set: 0.7917
# Epoch: 744	Loss: 0.7859	Accuracy on validation set: 0.7917
# Epoch: 745	Loss: 0.7856	Accuracy on validation set: 0.7917
# Epoch: 746	Loss: 0.7853	Accuracy on validation set: 0.7917
# Epoch: 747	Loss: 0.7850	Accuracy on validation set: 0.7917
# Epoch: 748	Loss: 0.7847	Accuracy on validation set: 0.7917
# Epoch: 749	Loss: 0.7844	Accuracy on validation set: 0.7917
# Epoch: 750	Loss: 0.7841	Accuracy on validation set: 0.7917
# Epoch: 751	Loss: 0.7839	Accuracy on validation set: 0.7917
# Epoch: 752	Loss: 0.7836	Accuracy on validation set: 0.7917
# Epoch: 753	Loss: 0.7833	Accuracy on validation set: 0.7917
# Epoch: 754	Loss: 0.7830	Accuracy on validation set: 0.7917
# Epoch: 755	Loss: 0.7827	Accuracy on validation set: 0.7917
# Epoch: 756	Loss: 0.7824	Accuracy on validation set: 0.7917
# Epoch: 757	Loss: 0.7822	Accuracy on validation set: 0.7917
# Epoch: 758	Loss: 0.7819	Accuracy on validation set: 0.7917
# Epoch: 759	Loss: 0.7816	Accuracy on validation set: 0.7917
# Epoch: 760	Loss: 0.7813	Accuracy on validation set: 0.7917
# Epoch: 761	Loss: 0.7810	Accuracy on validation set: 0.7917
# Epoch: 762	Loss: 0.7808	Accuracy on validation set: 0.7917
# Epoch: 763	Loss: 0.7805	Accuracy on validation set: 0.7917
# Epoch: 764	Loss: 0.7802	Accuracy on validation set: 0.7917
# Epoch: 765	Loss: 0.7799	Accuracy on validation set: 0.7917
# Epoch: 766	Loss: 0.7796	Accuracy on validation set: 0.7917
# Epoch: 767	Loss: 0.7793	Accuracy on validation set: 0.7917
# Epoch: 768	Loss: 0.7791	Accuracy on validation set: 0.7917
# Epoch: 769	Loss: 0.7788	Accuracy on validation set: 0.7917
# Epoch: 770	Loss: 0.7785	Accuracy on validation set: 0.7917
# Epoch: 771	Loss: 0.7782	Accuracy on validation set: 0.7917
# Epoch: 772	Loss: 0.7779	Accuracy on validation set: 0.7917
# Epoch: 773	Loss: 0.7777	Accuracy on validation set: 0.7917
# Epoch: 774	Loss: 0.7774	Accuracy on validation set: 0.7917
# Epoch: 775	Loss: 0.7771	Accuracy on validation set: 0.7917
# Epoch: 776	Loss: 0.7768	Accuracy on validation set: 0.7917
# Epoch: 777	Loss: 0.7765	Accuracy on validation set: 0.7917
# Epoch: 778	Loss: 0.7763	Accuracy on validation set: 0.7917
# Epoch: 779	Loss: 0.7760	Accuracy on validation set: 0.7917
# Epoch: 780	Loss: 0.7757	Accuracy on validation set: 0.8333
# Accuracy on validation set has just improved!
# The model has been saved under ./iris_model.pth.
# Epoch: 781	Loss: 0.7754	Accuracy on validation set: 0.8333
# Epoch: 782	Loss: 0.7751	Accuracy on validation set: 0.8333
# Epoch: 783	Loss: 0.7749	Accuracy on validation set: 0.8333
# Epoch: 784	Loss: 0.7746	Accuracy on validation set: 0.8333
# Epoch: 785	Loss: 0.7743	Accuracy on validation set: 0.8333
# Epoch: 786	Loss: 0.7740	Accuracy on validation set: 0.8333
# Epoch: 787	Loss: 0.7737	Accuracy on validation set: 0.8333
# Epoch: 788	Loss: 0.7735	Accuracy on validation set: 0.8333
# Epoch: 789	Loss: 0.7732	Accuracy on validation set: 0.8333
# Epoch: 790	Loss: 0.7729	Accuracy on validation set: 0.8333
# Epoch: 791	Loss: 0.7726	Accuracy on validation set: 0.8333
# Epoch: 792	Loss: 0.7724	Accuracy on validation set: 0.8333
# Epoch: 793	Loss: 0.7721	Accuracy on validation set: 0.8333
# Epoch: 794	Loss: 0.7718	Accuracy on validation set: 0.8333
# Epoch: 795	Loss: 0.7715	Accuracy on validation set: 0.8333
# Epoch: 796	Loss: 0.7712	Accuracy on validation set: 0.8333
# ...
# Epoch: 2238	Loss: 0.5898	Accuracy on validation set: 0.9583
# Epoch: 2239	Loss: 0.5898	Accuracy on validation set: 0.9583
# Epoch: 2240	Loss: 0.5897	Accuracy on validation set: 0.9583
# Epoch: 2241	Loss: 0.5897	Accuracy on validation set: 0.9583
# Epoch: 2242	Loss: 0.5897	Accuracy on validation set: 0.9583
# Epoch: 2243	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2244	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2245	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2246	Loss: 0.5896	Accuracy on validation set: 0.9583
# Epoch: 2247	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2248	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2249	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2250	Loss: 0.5895	Accuracy on validation set: 0.9583
# Epoch: 2251	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2252	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2253	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2254	Loss: 0.5894	Accuracy on validation set: 0.9583
# Epoch: 2255	Loss: 0.5893	Accuracy on validation set: 0.9583
# Epoch: 2256	Loss: 0.5893	Accuracy on validation set: 0.9583
# Epoch: 2257	Loss: 0.5893	Accuracy on validation set: 0.9583
# Epoch: 2258	Loss: 0.5893	Accuracy on validation set: 0.9583
# Epoch: 2259	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2260	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2261	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2262	Loss: 0.5892	Accuracy on validation set: 0.9583
# Epoch: 2263	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2264	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2265	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2266	Loss: 0.5891	Accuracy on validation set: 0.9583
# Epoch: 2267	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2268	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2269	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2270	Loss: 0.5890	Accuracy on validation set: 0.9583
# Epoch: 2271	Loss: 0.5889	Accuracy on validation set: 0.9583
# Epoch: 2272	Loss: 0.5889	Accuracy on validation set: 0.9583
# Epoch: 2273	Loss: 0.5889	Accuracy on validation set: 0.9583
# Epoch: 2274	Loss: 0.5889	Accuracy on validation set: 0.9583
# Epoch: 2275	Loss: 0.5888	Accuracy on validation set: 0.9583
# Epoch: 2276	Loss: 0.5888	Accuracy on validation set: 0.9583
# Epoch: 2277	Loss: 0.5888	Accuracy on validation set: 0.9583
# Epoch: 2278	Loss: 0.5888	Accuracy on validation set: 0.9583
# Epoch: 2279	Loss: 0.5887	Accuracy on validation set: 0.9583
# Epoch: 2280	Loss: 0.5887	Accuracy on validation set: 0.9583
# Epoch: 2281	Loss: 0.5887	Accuracy on validation set: 0.9583
# Epoch: 2282	Loss: 0.5887	Accuracy on validation set: 0.9583
# Epoch: 2283	Loss: 0.5886	Accuracy on validation set: 0.9583
# Epoch: 2284	Loss: 0.5886	Accuracy on validation set: 0.9583
# Epoch: 2285	Loss: 0.5886	Accuracy on validation set: 0.9583
# Epoch: 2286	Loss: 0.5886	Accuracy on validation set: 0.9583
# Epoch: 2287	Loss: 0.5886	Accuracy on validation set: 0.9583
# Epoch: 2288	Loss: 0.5885	Accuracy on validation set: 0.9583
# Epoch: 2289	Loss: 0.5885	Accuracy on validation set: 0.9583
# Epoch: 2290	Loss: 0.5885	Accuracy on validation set: 0.9583
# Epoch: 2291	Loss: 0.5885	Accuracy on validation set: 0.9583
# Epoch: 2292	Loss: 0.5884	Accuracy on validation set: 0.9583
# Epoch: 2293	Loss: 0.5884	Accuracy on validation set: 0.9583
# Epoch: 2294	Loss: 0.5884	Accuracy on validation set: 0.9583
# Epoch: 2295	Loss: 0.5884	Accuracy on validation set: 0.9583
# Epoch: 2296	Loss: 0.5883	Accuracy on validation set: 0.9583
# Epoch: 2297	Loss: 0.5883	Accuracy on validation set: 0.9583
# Epoch: 2298	Loss: 0.5883	Accuracy on validation set: 0.9583
# Epoch: 2299	Loss: 0.5883	Accuracy on validation set: 0.9583
# Epoch: 2300	Loss: 0.5882	Accuracy on validation set: 0.9583
# Epoch: 2301	Loss: 0.5882	Accuracy on validation set: 0.9583
# Epoch: 2302	Loss: 0.5882	Accuracy on validation set: 0.9583
# Epoch: 2303	Loss: 0.5882	Accuracy on validation set: 0.9583
# Epoch: 2304	Loss: 0.5881	Accuracy on validation set: 0.9583
# Epoch: 2305	Loss: 0.5881	Accuracy on validation set: 0.9583
# Epoch: 2306	Loss: 0.5881	Accuracy on validation set: 0.9583
# Epoch: 2307	Loss: 0.5881	Accuracy on validation set: 0.9583
# Epoch: 2308	Loss: 0.5881	Accuracy on validation set: 0.9583
# Epoch: 2309	Loss: 0.5880	Accuracy on validation set: 0.9583
# Epoch: 2310	Loss: 0.5880	Accuracy on validation set: 0.9583
# Epoch: 2311	Loss: 0.5880	Accuracy on validation set: 0.9583
# Epoch: 2312	Loss: 0.5880	Accuracy on validation set: 0.9583
# Epoch: 2313	Loss: 0.5879	Accuracy on validation set: 0.9583
# Epoch: 2314	Loss: 0.5879	Accuracy on validation set: 0.9583
# Epoch: 2315	Loss: 0.5879	Accuracy on validation set: 0.9583
# Epoch: 2316	Loss: 0.5879	Accuracy on validation set: 0.9583
# Epoch: 2317	Loss: 0.5878	Accuracy on validation set: 0.9583
# Epoch: 2318	Loss: 0.5878	Accuracy on validation set: 0.9583
# Epoch: 2319	Loss: 0.5878	Accuracy on validation set: 0.9583
# Epoch: 2320	Loss: 0.5878	Accuracy on validation set: 0.9583
# Epoch: 2321	Loss: 0.5878	Accuracy on validation set: 0.9583
# Epoch: 2322	Loss: 0.5877	Accuracy on validation set: 0.9583
# Epoch: 2323	Loss: 0.5877	Accuracy on validation set: 0.9583
# Epoch: 2324	Loss: 0.5877	Accuracy on validation set: 0.9583
# Epoch: 2325	Loss: 0.5877	Accuracy on validation set: 0.9583
# Epoch: 2326	Loss: 0.5876	Accuracy on validation set: 0.9583
# Epoch: 2327	Loss: 0.5876	Accuracy on validation set: 0.9583
# Epoch: 2328	Loss: 0.5876	Accuracy on validation set: 0.9583
# Epoch: 2329	Loss: 0.5876	Accuracy on validation set: 0.9583
# Epoch: 2330	Loss: 0.5875	Accuracy on validation set: 0.9583
# Epoch: 2331	Loss: 0.5875	Accuracy on validation set: 0.9583
# Epoch: 2332	Loss: 0.5875	Accuracy on validation set: 0.9583
# Epoch: 2333	Loss: 0.5875	Accuracy on validation set: 0.9583
# Epoch: 2334	Loss: 0.5875	Accuracy on validation set: 0.9583
# Epoch: 2335	Loss: 0.5874	Accuracy on validation set: 0.9583
# Epoch: 2336	Loss: 0.5874	Accuracy on validation set: 0.9583
# Epoch: 2337	Loss: 0.5874	Accuracy on validation set: 0.9583
# Epoch: 2338	Loss: 0.5874	Accuracy on validation set: 0.9583
# Epoch: 2339	Loss: 0.5873	Accuracy on validation set: 0.9583
# Epoch: 2340	Loss: 0.5873	Accuracy on validation set: 0.9583
# Epoch: 2341	Loss: 0.5873	Accuracy on validation set: 0.9583
# Epoch: 2342	Loss: 0.5873	Accuracy on validation set: 0.9583
# Epoch: 2343	Loss: 0.5873	Accuracy on validation set: 0.9583
# Epoch: 2344	Loss: 0.5872	Accuracy on validation set: 0.9583
# Epoch: 2345	Loss: 0.5872	Accuracy on validation set: 0.9583
# Epoch: 2346	Loss: 0.5872	Accuracy on validation set: 0.9583
# Epoch: 2347	Loss: 0.5872	Accuracy on validation set: 0.9583
# Epoch: 2348	Loss: 0.5871	Accuracy on validation set: 0.9583
# Epoch: 2349	Loss: 0.5871	Accuracy on validation set: 0.9583
# Epoch: 2350	Loss: 0.5871	Accuracy on validation set: 0.9583
# Epoch: 2351	Loss: 0.5871	Accuracy on validation set: 0.9583
# Epoch: 2352	Loss: 0.5871	Accuracy on validation set: 0.9583
# Epoch: 2353	Loss: 0.5870	Accuracy on validation set: 0.9583
# Epoch: 2354	Loss: 0.5870	Accuracy on validation set: 0.9583
# Epoch: 2355	Loss: 0.5870	Accuracy on validation set: 0.9583
# Epoch: 2356	Loss: 0.5870	Accuracy on validation set: 0.9583
# Epoch: 2357	Loss: 0.5869	Accuracy on validation set: 0.9583
# Epoch: 2358	Loss: 0.5869	Accuracy on validation set: 0.9583
# Epoch: 2359	Loss: 0.5869	Accuracy on validation set: 0.9583
# Epoch: 2360	Loss: 0.5869	Accuracy on validation set: 0.9583
# Epoch: 2361	Loss: 0.5869	Accuracy on validation set: 0.9583
# Epoch: 2362	Loss: 0.5868	Accuracy on validation set: 0.9583
# Epoch: 2363	Loss: 0.5868	Accuracy on validation set: 0.9583
# Epoch: 2364	Loss: 0.5868	Accuracy on validation set: 0.9583
# Epoch: 2365	Loss: 0.5868	Accuracy on validation set: 0.9583
# Epoch: 2366	Loss: 0.5867	Accuracy on validation set: 0.9583
# Epoch: 2367	Loss: 0.5867	Accuracy on validation set: 0.9583
# Epoch: 2368	Loss: 0.5867	Accuracy on validation set: 0.9583
# Epoch: 2369	Loss: 0.5867	Accuracy on validation set: 0.9583
# Epoch: 2370	Loss: 0.5867	Accuracy on validation set: 0.9583
# Epoch: 2371	Loss: 0.5866	Accuracy on validation set: 0.9583
# Epoch: 2372	Loss: 0.5866	Accuracy on validation set: 0.9583
# Epoch: 2373	Loss: 0.5866	Accuracy on validation set: 0.9583
# Epoch: 2374	Loss: 0.5866	Accuracy on validation set: 0.9583
# Epoch: 2375	Loss: 0.5866	Accuracy on validation set: 0.9583
# Epoch: 2376	Loss: 0.5865	Accuracy on validation set: 0.9583
# Epoch: 2377	Loss: 0.5865	Accuracy on validation set: 0.9583
# Epoch: 2378	Loss: 0.5865	Accuracy on validation set: 0.9583
# Epoch: 2379	Loss: 0.5865	Accuracy on validation set: 0.9583
# Epoch: 2380	Loss: 0.5864	Accuracy on validation set: 0.9583
# Epoch: 2381	Loss: 0.5864	Accuracy on validation set: 0.9583
# Epoch: 2382	Loss: 0.5864	Accuracy on validation set: 0.9583
# Epoch: 2383	Loss: 0.5864	Accuracy on validation set: 0.9583
# Epoch: 2384	Loss: 0.5864	Accuracy on validation set: 0.9583
# Epoch: 2385	Loss: 0.5863	Accuracy on validation set: 0.9583
# Epoch: 2386	Loss: 0.5863	Accuracy on validation set: 0.9583
# Epoch: 2387	Loss: 0.5863	Accuracy on validation set: 0.9583
# Epoch: 2388	Loss: 0.5863	Accuracy on validation set: 0.9583
# Epoch: 2389	Loss: 0.5863	Accuracy on validation set: 0.9583
# Epoch: 2390	Loss: 0.5862	Accuracy on validation set: 0.9583
# Epoch: 2391	Loss: 0.5862	Accuracy on validation set: 0.9583
# Epoch: 2392	Loss: 0.5862	Accuracy on validation set: 0.9583
# Epoch: 2393	Loss: 0.5862	Accuracy on validation set: 0.9583
# Epoch: 2394	Loss: 0.5862	Accuracy on validation set: 0.9583
# Epoch: 2395	Loss: 0.5861	Accuracy on validation set: 0.9583
# Epoch: 2396	Loss: 0.5861	Accuracy on validation set: 0.9583
# Epoch: 2397	Loss: 0.5861	Accuracy on validation set: 0.9583
# Epoch: 2398	Loss: 0.5861	Accuracy on validation set: 0.9583
# Epoch: 2399	Loss: 0.5861	Accuracy on validation set: 0.9583
# Epoch: 2400	Loss: 0.5860	Accuracy on validation set: 0.9583
# Epoch: 2401	Loss: 0.5860	Accuracy on validation set: 0.9583
# Epoch: 2402	Loss: 0.5860	Accuracy on validation set: 0.9583
# Epoch: 2403	Loss: 0.5860	Accuracy on validation set: 0.9583
# Epoch: 2404	Loss: 0.5859	Accuracy on validation set: 0.9583
# Epoch: 2405	Loss: 0.5859	Accuracy on validation set: 0.9583
# Epoch: 2406	Loss: 0.5859	Accuracy on validation set: 0.9583
# Epoch: 2407	Loss: 0.5859	Accuracy on validation set: 0.9583
# Epoch: 2408	Loss: 0.5859	Accuracy on validation set: 0.9583
# Epoch: 2409	Loss: 0.5858	Accuracy on validation set: 0.9583
# Epoch: 2410	Loss: 0.5858	Accuracy on validation set: 0.9583
# Epoch: 2411	Loss: 0.5858	Accuracy on validation set: 0.9583
# Epoch: 2412	Loss: 0.5858	Accuracy on validation set: 0.9583
# Epoch: 2413	Loss: 0.5858	Accuracy on validation set: 0.9583
# Epoch: 2414	Loss: 0.5857	Accuracy on validation set: 0.9583
# Epoch: 2415	Loss: 0.5857	Accuracy on validation set: 0.9583
# Epoch: 2416	Loss: 0.5857	Accuracy on validation set: 0.9583
# Epoch: 2417	Loss: 0.5857	Accuracy on validation set: 0.9583
# Epoch: 2418	Loss: 0.5857	Accuracy on validation set: 0.9583
# Epoch: 2419	Loss: 0.5856	Accuracy on validation set: 0.9583
# Epoch: 2420	Loss: 0.5856	Accuracy on validation set: 0.9583
# Epoch: 2421	Loss: 0.5856	Accuracy on validation set: 0.9583
# Epoch: 2422	Loss: 0.5856	Accuracy on validation set: 0.9583
# Epoch: 2423	Loss: 0.5856	Accuracy on validation set: 0.9583
# Epoch: 2424	Loss: 0.5855	Accuracy on validation set: 0.9583
# Epoch: 2425	Loss: 0.5855	Accuracy on validation set: 0.9583
# Epoch: 2426	Loss: 0.5855	Accuracy on validation set: 0.9583
# Epoch: 2427	Loss: 0.5855	Accuracy on validation set: 0.9583
# Epoch: 2428	Loss: 0.5855	Accuracy on validation set: 0.9583
# Epoch: 2429	Loss: 0.5854	Accuracy on validation set: 0.9583
# Epoch: 2430	Loss: 0.5854	Accuracy on validation set: 0.9583
# Epoch: 2431	Loss: 0.5854	Accuracy on validation set: 0.9583
# Epoch: 2432	Loss: 0.5854	Accuracy on validation set: 0.9583
# Epoch: 2433	Loss: 0.5854	Accuracy on validation set: 0.9583
# Epoch: 2434	Loss: 0.5853	Accuracy on validation set: 0.9583
# Epoch: 2435	Loss: 0.5853	Accuracy on validation set: 0.9583
# Epoch: 2436	Loss: 0.5853	Accuracy on validation set: 0.9583
# Epoch: 2437	Loss: 0.5853	Accuracy on validation set: 0.9583
# Epoch: 2438	Loss: 0.5853	Accuracy on validation set: 0.9583
# Epoch: 2439	Loss: 0.5852	Accuracy on validation set: 0.9583
# Epoch: 2440	Loss: 0.5852	Accuracy on validation set: 0.9583
# Epoch: 2441	Loss: 0.5852	Accuracy on validation set: 0.9583
# Epoch: 2442	Loss: 0.5852	Accuracy on validation set: 0.9583
# Epoch: 2443	Loss: 0.5852	Accuracy on validation set: 0.9583
# Epoch: 2444	Loss: 0.5851	Accuracy on validation set: 0.9583
# Epoch: 2445	Loss: 0.5851	Accuracy on validation set: 0.9583
# Epoch: 2446	Loss: 0.5851	Accuracy on validation set: 0.9583
# Epoch: 2447	Loss: 0.5851	Accuracy on validation set: 0.9583
# Epoch: 2448	Loss: 0.5851	Accuracy on validation set: 0.9583
# Epoch: 2449	Loss: 0.5851	Accuracy on validation set: 0.9583
# Epoch: 2450	Loss: 0.5850	Accuracy on validation set: 0.9583
# Epoch: 2451	Loss: 0.5850	Accuracy on validation set: 0.9583
# Epoch: 2452	Loss: 0.5850	Accuracy on validation set: 0.9583
# Epoch: 2453	Loss: 0.5850	Accuracy on validation set: 0.9583
# Epoch: 2454	Loss: 0.5850	Accuracy on validation set: 0.9583
# Epoch: 2455	Loss: 0.5849	Accuracy on validation set: 0.9583
# Epoch: 2456	Loss: 0.5849	Accuracy on validation set: 0.9583
# Epoch: 2457	Loss: 0.5849	Accuracy on validation set: 0.9583
# Epoch: 2458	Loss: 0.5849	Accuracy on validation set: 0.9583
# Epoch: 2459	Loss: 0.5849	Accuracy on validation set: 0.9583
# Epoch: 2460	Loss: 0.5848	Accuracy on validation set: 0.9583
# Epoch: 2461	Loss: 0.5848	Accuracy on validation set: 0.9583
# Epoch: 2462	Loss: 0.5848	Accuracy on validation set: 0.9583
# Epoch: 2463	Loss: 0.5848	Accuracy on validation set: 0.9583
# Epoch: 2464	Loss: 0.5848	Accuracy on validation set: 0.9583
# Epoch: 2465	Loss: 0.5847	Accuracy on validation set: 0.9583
# Epoch: 2466	Loss: 0.5847	Accuracy on validation set: 0.9583
# Epoch: 2467	Loss: 0.5847	Accuracy on validation set: 0.9583
# Epoch: 2468	Loss: 0.5847	Accuracy on validation set: 0.9583
# Epoch: 2469	Loss: 0.5847	Accuracy on validation set: 0.9583
# Epoch: 2470	Loss: 0.5847	Accuracy on validation set: 0.9583
# Epoch: 2471	Loss: 0.5846	Accuracy on validation set: 0.9583
# Epoch: 2472	Loss: 0.5846	Accuracy on validation set: 0.9583
# Epoch: 2473	Loss: 0.5846	Accuracy on validation set: 0.9583
# Epoch: 2474	Loss: 0.5846	Accuracy on validation set: 0.9583
# Epoch: 2475	Loss: 0.5846	Accuracy on validation set: 0.9583
# Epoch: 2476	Loss: 0.5845	Accuracy on validation set: 0.9583
# Epoch: 2477	Loss: 0.5845	Accuracy on validation set: 0.9583
# Epoch: 2478	Loss: 0.5845	Accuracy on validation set: 0.9583
# Epoch: 2479	Loss: 0.5845	Accuracy on validation set: 0.9583
# Epoch: 2480	Loss: 0.5845	Accuracy on validation set: 0.9583
# Epoch: 2481	Loss: 0.5844	Accuracy on validation set: 0.9583
# Epoch: 2482	Loss: 0.5844	Accuracy on validation set: 0.9583
# Epoch: 2483	Loss: 0.5844	Accuracy on validation set: 0.9583
# Epoch: 2484	Loss: 0.5844	Accuracy on validation set: 0.9583
# Epoch: 2485	Loss: 0.5844	Accuracy on validation set: 0.9583
# Epoch: 2486	Loss: 0.5844	Accuracy on validation set: 0.9583
# Epoch: 2487	Loss: 0.5843	Accuracy on validation set: 0.9583
# Epoch: 2488	Loss: 0.5843	Accuracy on validation set: 0.9583
# Epoch: 2489	Loss: 0.5843	Accuracy on validation set: 0.9583
# Epoch: 2490	Loss: 0.5843	Accuracy on validation set: 0.9583
# Epoch: 2491	Loss: 0.5843	Accuracy on validation set: 0.9583
# Epoch: 2492	Loss: 0.5842	Accuracy on validation set: 0.9583
# Epoch: 2493	Loss: 0.5842	Accuracy on validation set: 0.9583
# Epoch: 2494	Loss: 0.5842	Accuracy on validation set: 0.9583
# Epoch: 2495	Loss: 0.5842	Accuracy on validation set: 0.9583
# Epoch: 2496	Loss: 0.5842	Accuracy on validation set: 0.9583
# Epoch: 2497	Loss: 0.5842	Accuracy on validation set: 0.9583
# Epoch: 2498	Loss: 0.5841	Accuracy on validation set: 0.9583
# Epoch: 2499	Loss: 0.5841	Accuracy on validation set: 0.9583
# Epoch: 2500	Loss: 0.5841	Accuracy on validation set: 0.9583
# Epoch: 2501	Loss: 0.5841	Accuracy on validation set: 0.9583
# Epoch: 2502	Loss: 0.5841	Accuracy on validation set: 0.9583
# Epoch: 2503	Loss: 0.5840	Accuracy on validation set: 0.9583
# Early stopping!

# %% [markdown]
# Finally, use the model (whether newly trained from scratch or trained previously and imported) to make predictions on the unseen test set.

# %%
# predict output of test data
Y_predict = model(X_test)
_, labels = torch.max(Y_predict, 1)
accuracy_score(labels, Y_test)
# Out:
# 0.9333333333333333

# %% [markdown]
# *Tip:* Seldomly, the model does not perform well. Run the training cell again, choosing not to load the saved model. This will give you extra training epochs on the already trained model and the loss should continue to decrease. If necessary, do this over and over again until the model performs well. Otherwise, you can also start from scratch and hope for better initialization of the weights and biases.
